# %%
from bs4 import BeautifulSoup
import requests
import sqlite3
import pandas as pd

TIKI_URL = 'https://tiki.vn'

# %%
PATH_TO_DB = '.'

conn = sqlite3.connect('tiki.db')
cur = conn.cursor()

# %%
HEADERS = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'}

# %%
# Get the HTML content get_url()
def get_url(url):
    try:
        response = requests.get(url,headers = HEADERS).text
        soup = BeautifulSoup(response, 'html.parser')
        return soup
    except Exception as err:
        print('ERROR BY REQUEST:', err)
        return None

# %%
get_url(TIKI_URL).prettify()[0:500]
# Out:
# '<!DOCTYPE html>\n<html class="no-js" lang="vi">\n <head>\n  <meta charset="utf-8" class="next-head"/>\n  <meta class="next-head" content="Thỏa sức mua sắm qua mạng hàng ngàn mặt hàng sách, điện tử, đồ gia dụng, quà tặng, thời trang, làm đẹp &amp; sức khỏe tại Tiki với giá rẻ hơn và khuyến mãi hấp dẫn" name="description"/>\n  <link class="next-head" href="https://frontend.tikicdn.com/_desktop-next/static/css/_sprite.css?v=2020118626lDLLgT6FQj94Zcp6HCXZd" rel="stylesheet" type="text/css"/>\n  <link clas'

# %% [markdown]
# #### Create Read Update Delete
# On database

# %%
# Create table categories in the database using a function
def create_categories_table():
    query = """
        CREATE TABLE IF NOT EXISTS categories (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            name VARCHAR(255),
            url TEXT, 
            parent_id INTEGER, 
            create_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
        )
    """
    try:
        cur.execute(query)
        conn.commit()
    except Exception as err:
        print('ERROR BY CREATE TABLE', err)
        
create_categories_table()

# %%
# Insert a row of data to the table categories
query = """
    INSERT INTO categories (name, url, parent_id)
    VALUES (?, ?, ?);
"""

val = ('Phone','phone.xyz', 5)
try:
    cur.execute(query, val)
    cat_id = cur.lastrowid
    print(cat_id)
    conn.commit()

except Exception as err:
    print('ERROR BY INSERT:', err)
# Out:
# 2

# %%
query = """
    SELECT * 
    FROM categories
"""

for row in cur.execute(query):
    print(row)
conn.commit()
# Out:
# (1, 'Phone', 'phone.xyz', 5, '2020-11-29 10:18:28')
# (2, 'Phone', 'phone.xyz', 5, '2020-11-29 10:18:42')

# %%
cur.execute('SELECT * FROM categories;').fetchall()
# Out:
# [(1, 'Phone', 'phone.xyz', 5, '2020-11-29 10:18:28'),
#  (2, 'Phone', 'phone.xyz', 5, '2020-11-29 10:18:42')]

# %%
# Remove a row by using its id
query="""
    DELETE FROM categories WHERE id=?;
"""

val = (1,)

try:
    cur.execute(query, val)
    conn.commit()

except Exception as err:
    print('ERROR BY INSERT:', err)

cur.execute('SELECT * FROM categories;').fetchall()
# Out:
# [(2, 'Phone', 'phone.xyz', 5, '2020-11-29 10:18:42')]

# %%
# drop the whole table to clean things up
cur.execute('DROP TABLE categories;')
conn.commit()

# recreate the table
create_categories_table()

# %%
# Instead of using a function to do CRUD on database,
# creating a class Category is preferred
# attributes: name, url, parent_id
# instance method: save_into_db()
class Category:
    def __init__(self, name, url, parent_id=None, cat_id=None):
        self.cat_id = cat_id
        self.name = name
        self.url = url
        self.parent_id = parent_id

    def __repr__(self):
        return f"ID: {self.cat_id}, Name: {self.name}, URL: {self.url}, Parent: {self.parent_id}"

    def save_into_db(self):
        query = """
            INSERT INTO categories (name, url, parent_id)
            VALUES (?, ?, ?);
        """
        val = (self.name, self.url, self.parent_id)
        try:
            cur.execute(query, val)
            self.cat_id = cur.lastrowid
            conn.commit()
        except Exception as err:
            print('ERROR BY INSERT:', err)

# %%
cat1 = Category('Phone-Tablet', 'https://tiki.vn/dien-thoai-may-tinh-bang/c1789')
cat1.save_into_db()
print(cat1.cat_id)
# Out:
# 1

# %%
cur.execute('SELECT * FROM categories;').fetchall()
# Out:
# [(1,
#   'Phone-Tablet',
#   'https://tiki.vn/dien-thoai-may-tinh-bang/c1789',
#   None,
#   '2020-11-29 10:18:42')]

# %%
# display the category object
print(cat1)
# Out:
# ID: 1, Name: Phone-Tablet, URL: https://tiki.vn/dien-thoai-may-tinh-bang/c1789, Parent: None

# %%
# prepare our categories table again
cur.execute('DROP TABLE categories;')
conn.commit()
create_categories_table()

# %%
CATEGORY_SET = set()
def can_add_to_cat_set(cat_name,save=False):
    if cat_name not in CATEGORY_SET:
        if save:
            CATEGORY_SET.add(cat_name)
            print(f'Added "{cat_name}" to CATEGORY_SET')
        return True
    return False

# %%
def get_main_categories(save_db=False):
    soup = get_url(TIKI_URL)

    result = []
    for a in soup.find_all('a', {'class': 'menu-link'}):
        name = a.find('span', {'class': 'text'}).text.strip()

        _ = can_add_to_cat_set(name,save_db)

        url = a['href']
        main_cat = Category(name, url) # object from class Category

        if save_db:
            main_cat.save_into_db()
        result.append(main_cat)
    
    return result

# %%
main_categories = get_main_categories(save_db=True)
# Out:
# Added "Điện Thoại - Máy Tính Bảng" to CATEGORY_SET
# Added "Điện Tử - Điện Lạnh" to CATEGORY_SET
# Added "Phụ Kiện - Thiết Bị Số" to CATEGORY_SET
# Added "Laptop - Thiết bị IT" to CATEGORY_SET
# Added "Máy Ảnh - Quay Phim" to CATEGORY_SET
# Added "Điện Gia Dụng" to CATEGORY_SET
# Added "Nhà Cửa Đời Sống" to CATEGORY_SET
# Added "Hàng Tiêu Dùng - Thực Phẩm" to CATEGORY_SET
# Added "Đồ chơi, Mẹ & Bé" to CATEGORY_SET
# Added "Làm Đẹp - Sức Khỏe" to CATEGORY_SET
# Added "Thời trang - Phụ kiện" to CATEGORY_SET
# Added "Thể Thao - Dã Ngoại" to CATEGORY_SET
# Added "Xe Máy, Ô tô, Xe Đạp" to CATEGORY_SET
# Added "Hàng quốc tế" to CATEGORY_SET
# Added "Sách, VPP & Quà Tặng" to CATEGORY_SET
# Added "Voucher - Dịch Vụ - Thẻ Cào" to CATEGORY_SET

# %%
main_categories
# Out:
# [ID: 1, Name: Điện Thoại - Máy Tính Bảng, URL: https://tiki.vn/dien-thoai-may-tinh-bang/c1789?src=c.1789.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 2, Name: Điện Tử - Điện Lạnh, URL: https://tiki.vn/tivi-thiet-bi-nghe-nhin/c4221?src=c.4221.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 3, Name: Phụ Kiện - Thiết Bị Số, URL: https://tiki.vn/thiet-bi-kts-phu-kien-so/c1815?src=c.1815.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 4, Name: Laptop - Thiết bị IT, URL: https://tiki.vn/laptop-may-vi-tinh/c1846?src=c.1846.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 5, Name: Máy Ảnh - Quay Phim, URL: https://tiki.vn/may-anh/c1801?src=c.1801.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 6, Name: Điện Gia Dụng, URL: https://tiki.vn/dien-gia-dung/c1882?src=c.1882.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 7, Name: Nhà Cửa Đời Sống, URL: https://tiki.vn/nha-cua-doi-song/c1883?src=c.1883.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 8, Name: Hàng Tiêu Dùng - Thực Phẩm, URL: https://tiki.vn/bach-hoa-online/c4384?src=c.4384.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 9, Name: Đồ chơi, Mẹ & Bé, URL: https://tiki.vn/me-va-be/c2549?src=c.2549.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 10, Name: Làm Đẹp - Sức Khỏe, URL: https://tiki.vn/lam-dep-suc-khoe/c1520?src=c.1520.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 11, Name: Thời trang - Phụ kiện, URL: #, Parent: None,
#  ID: 12, Name: Thể Thao - Dã Ngoại, URL: https://tiki.vn/the-thao/c1975?src=c.1975.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 13, Name: Xe Máy, Ô tô, Xe Đạp, URL: https://tiki.vn/o-to-xe-may-xe-dap/c8594?src=c.8594.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 14, Name: Hàng quốc tế, URL: https://tiki.vn/hang-quoc-te/c17166?src=c.17166.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 15, Name: Sách, VPP & Quà Tặng, URL: https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 16, Name: Voucher - Dịch Vụ - Thẻ Cào, URL: https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner, Parent: None]

# %%
cur.execute('SELECT * FROM categories;').fetchall()
# Out:
# [(1,
#   'Điện Thoại - Máy Tính Bảng',
#   'https://tiki.vn/dien-thoai-may-tinh-bang/c1789?src=c.1789.hamburger_menu_fly_out_banner',
#   None,
#   '2020-11-29 10:18:43'),
#  (2,
#   'Điện Tử - Điện Lạnh',
#   'https://tiki.vn/tivi-thiet-bi-nghe-nhin/c4221?src=c.4221.hamburger_menu_fly_out_banner',
#   None,
#   '2020-11-29 10:18:43'),
#  (3,
#   'Phụ Kiện - Thiết Bị Số',
#   'https://tiki.vn/thiet-bi-kts-phu-kien-so/c1815?src=c.1815.hamburger_menu_fly_out_banner',
#   None,
#   '2020-11-29 10:18:43'),
#  (4,
#   'Laptop - Thiết bị IT',
#   'https://tiki.vn/laptop-may-vi-tinh/c1846?src=c.1846.hamburger_menu_fly_out_banner',
#   None,
#   '2020-11-29 10:18:43'),
#  (5,
#   'Máy Ảnh - Quay Phim',
#   'https://tiki.vn/may-anh/c1801?src=c.1801.hamburger_menu_fly_out_banner',
#   None,
#   '2020-11-29 10:18:43'),
#  (6,
#   'Điện Gia Dụng',
#   'https://tiki.vn/dien-gia-dung/c1882?src=c.1882.hamburger_menu_fly_out_banner',
#   None,
#   '2020-11-29 10:18:43'),
#  (7,
#   'Nhà Cửa Đời Sống',
#   'https://tiki.vn/nha-cua-doi-song/c1883?src=c.1883.hamburger_menu_fly_out_banner',
#   None,
#   '2020-11-29 10:18:43'),
#  (8,
#   'Hàng Tiêu Dùng - Thực Phẩm',
#   'https://tiki.vn/bach-hoa-online/c4384?src=c.4384.hamburger_menu_fly_out_banner',
#   None,
#   '2020-11-29 10:18:43'),
#  (9,
#   'Đồ chơi, Mẹ & Bé',
#   'https://tiki.vn/me-va-be/c2549?src=c.2549.hamburger_menu_fly_out_banner',
#   None,
#   '2020-11-29 10:18:43'),
#  (10,
#   'Làm Đẹp - Sức Khỏe',
#   'https://tiki.vn/lam-dep-suc-khoe/c1520?src=c.1520.hamburger_menu_fly_out_banner',
#   None,
#   '2020-11-29 10:18:43'),
#  (11, 'Thời trang - Phụ kiện', '#', None, '2020-11-29 10:18:43'),
#  (12,
#   'Thể Thao - Dã Ngoại',
#   'https://tiki.vn/the-thao/c1975?src=c.1975.hamburger_menu_fly_out_banner',
#   None,
#   '2020-11-29 10:18:43'),
#  (13,
#   'Xe Máy, Ô tô, Xe Đạp',
#   'https://tiki.vn/o-to-xe-may-xe-dap/c8594?src=c.8594.hamburger_menu_fly_out_banner',
#   None,
#   '2020-11-29 10:18:43'),
#  (14,
#   'Hàng quốc tế',
#   'https://tiki.vn/hang-quoc-te/c17166?src=c.17166.hamburger_menu_fly_out_banner',
#   None,
#   '2020-11-29 10:18:43'),
#  (15,
#   'Sách, VPP & Quà Tặng',
#   'https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner',
#   None,
#   '2020-11-29 10:18:43'),
#  (16,
#   'Voucher - Dịch Vụ - Thẻ Cào',
#   'https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner',
#   None,
#   '2020-11-29 10:18:43')]

# %%
import re

# get_sub_categories() given a parent category
def get_sub_categories(parent_category, save_db=False):
    parent_url = parent_category.url
    #print(parent_url)
    result = []

    try:
        soup = get_url(parent_url)

        for a in soup.find_all('a', {'class':'item item--category'}):
            name = a.text.strip()
            if can_add_to_cat_set(name,save_db): 
                sub_url = a['href']
                cat = Category(name, sub_url, parent_category.cat_id) # we now have parent_id, which is cat_id of parent category
                if save_db:
                    cat.save_into_db()
                result.append(cat)
    
    except Exception as err:
        print('ERROR IN GETTING SUB CATEGORIES:', err)
    
    return result

# %%
print(main_categories[2])
# Out:
# ID: 3, Name: Phụ Kiện - Thiết Bị Số, URL: https://tiki.vn/thiet-bi-kts-phu-kien-so/c1815?src=c.1815.hamburger_menu_fly_out_banner, Parent: None

# %%
temp1 = get_sub_categories(main_categories[2], False)

print('temp1:', temp1[-1] )
temp2 = get_sub_categories(temp1[-1], False)

print( 'temp2:', temp2[-1] )
temp3 = get_sub_categories(temp2[-1], False)

print('temp3:', temp3[5])
temp4 = get_sub_categories(temp3[5], False)

print('temp4:', temp4[0])
temp5 = get_sub_categories(temp4[0], False)

for item in temp5:
    print(item)
# Out:
# temp1: ID: None, Name: Thiết Bị Đeo Thông Minh và Phụ Kiện, URL: https://tiki.vn/thiet-bi-deo-thong-minh-va-phu-kien/c8039?src=c.1815.hamburger_menu_fly_out_banner, Parent: 3
# temp2: ID: None, Name: Thiết Bị Âm Thanh và Phụ Kiện, URL: https://tiki.vn/thiet-bi-am-thanh-va-phu-kien/c8215?src=c.1815.hamburger_menu_fly_out_banner, Parent: None
# temp3: ID: None, Name: Tai Nghe Bluetooth, URL: https://tiki.vn/tai-nghe-bluetooth/c1811?src=c.1815.hamburger_menu_fly_out_banner, Parent: None
# temp4: ID: None, Name: Tai Nghe Bluetooth Chụp Tai On-Ear, URL: https://tiki.vn/tai-nghe-bluetooth-chup-tai-on-ear/c28640?src=c.1815.hamburger_menu_fly_out_banner, Parent: None
# ID: None, Name: Tai Nghe Bluetooth Chụp Tai Over-Ear, URL: https://tiki.vn/tai-nghe-bluetooth-chup-tai-over-ear/c4429?src=c.1815.hamburger_menu_fly_out_banner, Parent: None
# ID: None, Name: Tai Nghe Bluetooth Nhét Tai, URL: https://tiki.vn/tai-nghe-bluetooth-nhet-tai/c5531?src=c.1815.hamburger_menu_fly_out_banner, Parent: None
# ID: None, Name: Tai Nghe Bluetooth Đàm Thoại, URL: https://tiki.vn/tai-nghe-bluetooth-dam-thoai/c12878?src=c.1815.hamburger_menu_fly_out_banner, Parent: None
# ID: None, Name: Tai Nghe True Wireless, URL: https://tiki.vn/tai-nghe-true-wireless/c8400?src=c.1815.hamburger_menu_fly_out_banner, Parent: None

# %%
#cur.execute('SELECT * FROM categories ORDER BY id DESC').fetchall()
query = """
    SELECT * 
    FROM categories
"""

pd.read_sql_query(query, conn)
# Out:
#     id                         name  \
# 0    1   Điện Thoại - Máy Tính Bảng
# 1    2          Điện Tử - Điện Lạnh
# 2    3       Phụ Kiện - Thiết Bị Số
# 3    4         Laptop - Thiết bị IT
# 4    5          Máy Ảnh - Quay Phim
# 5    6                Điện Gia Dụng
# 6    7             Nhà Cửa Đời Sống
# 7    8   Hàng Tiêu Dùng - Thực Phẩm
# 8    9             Đồ chơi, Mẹ & Bé
# 9   10           Làm Đẹp - Sức Khỏe
# 10  11        Thời trang - Phụ kiện
# 11  12          Thể Thao - Dã Ngoại
# 12  13         Xe Máy, Ô tô, Xe Đạp
# 13  14                 Hàng quốc tế
# 14  15         Sách, VPP & Quà Tặng
# 15  16  Voucher - Dịch Vụ - Thẻ Cào
#
#                                                   url parent_id  \
# 0   https://tiki.vn/dien-thoai-may-tinh-bang/c1789...      None
# 1   https://tiki.vn/tivi-thiet-bi-nghe-nhin/c4221?...      None
# 2   https://tiki.vn/thiet-bi-kts-phu-kien-so/c1815...      None
# 3   https://tiki.vn/laptop-may-vi-tinh/c1846?src=c...      None
# 4   https://tiki.vn/may-anh/c1801?src=c.1801.hambu...      None
# 5   https://tiki.vn/dien-gia-dung/c1882?src=c.1882...      None
# 6   https://tiki.vn/nha-cua-doi-song/c1883?src=c.1...      None
# 7   https://tiki.vn/bach-hoa-online/c4384?src=c.43...      None
# 8   https://tiki.vn/me-va-be/c2549?src=c.2549.hamb...      None
# 9   https://tiki.vn/lam-dep-suc-khoe/c1520?src=c.1...      None
# 10                                                  #      None
# 11  https://tiki.vn/the-thao/c1975?src=c.1975.hamb...      None
# 12  https://tiki.vn/o-to-xe-may-xe-dap/c8594?src=c...      None
# 13  https://tiki.vn/hang-quoc-te/c17166?src=c.1716...      None
# 14  https://tiki.vn/nha-sach-tiki/c8322?src=c.8322...      None
# 15  https://tiki.vn/voucher-dich-vu/c11312?src=c.1...      None
#
#               create_at
# 0   2020-11-29 10:18:43
# 1   2020-11-29 10:18:43
# 2   2020-11-29 10:18:43
# 3   2020-11-29 10:18:43
# 4   2020-11-29 10:18:43
# 5   2020-11-29 10:18:43
# 6   2020-11-29 10:18:43
# 7   2020-11-29 10:18:43
# 8   2020-11-29 10:18:43
# 9   2020-11-29 10:18:43
# 10  2020-11-29 10:18:43
# 11  2020-11-29 10:18:43
# 12  2020-11-29 10:18:43
# 13  2020-11-29 10:18:43
# 14  2020-11-29 10:18:43
# 15  2020-11-29 10:18:43

# %%
from time import sleep
from random import randint


def get_all_categories(categories,save_db):
    # if I reach the last possible category, I need to stop
    if len(categories) == 0:
        return      
    for cat in categories:
        #print(f'Getting {cat} sub-categories...')
        sub_categories = get_sub_categories(cat, save_db=save_db)
        sleep(randint(1,3))
        #print(f'Finished! {cat.name} has {len(sub_categories)} sub-categories')
        get_all_categories(sub_categories,save_db=save_db) # make sure to switch on (or off) save_db here
    
    print('Done')

# %%
# drop the whole table to clean things up
cur.execute('DROP TABLE categories;')
conn.commit()

# re-create our category table again
create_categories_table()

# %%
main_categories
# Out:
# [ID: 1, Name: Điện Thoại - Máy Tính Bảng, URL: https://tiki.vn/dien-thoai-may-tinh-bang/c1789?src=c.1789.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 2, Name: Điện Tử - Điện Lạnh, URL: https://tiki.vn/tivi-thiet-bi-nghe-nhin/c4221?src=c.4221.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 3, Name: Phụ Kiện - Thiết Bị Số, URL: https://tiki.vn/thiet-bi-kts-phu-kien-so/c1815?src=c.1815.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 4, Name: Laptop - Thiết bị IT, URL: https://tiki.vn/laptop-may-vi-tinh/c1846?src=c.1846.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 5, Name: Máy Ảnh - Quay Phim, URL: https://tiki.vn/may-anh/c1801?src=c.1801.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 6, Name: Điện Gia Dụng, URL: https://tiki.vn/dien-gia-dung/c1882?src=c.1882.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 7, Name: Nhà Cửa Đời Sống, URL: https://tiki.vn/nha-cua-doi-song/c1883?src=c.1883.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 8, Name: Hàng Tiêu Dùng - Thực Phẩm, URL: https://tiki.vn/bach-hoa-online/c4384?src=c.4384.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 9, Name: Đồ chơi, Mẹ & Bé, URL: https://tiki.vn/me-va-be/c2549?src=c.2549.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 10, Name: Làm Đẹp - Sức Khỏe, URL: https://tiki.vn/lam-dep-suc-khoe/c1520?src=c.1520.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 11, Name: Thời trang - Phụ kiện, URL: #, Parent: None,
#  ID: 12, Name: Thể Thao - Dã Ngoại, URL: https://tiki.vn/the-thao/c1975?src=c.1975.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 13, Name: Xe Máy, Ô tô, Xe Đạp, URL: https://tiki.vn/o-to-xe-may-xe-dap/c8594?src=c.8594.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 14, Name: Hàng quốc tế, URL: https://tiki.vn/hang-quoc-te/c17166?src=c.17166.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 15, Name: Sách, VPP & Quà Tặng, URL: https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner, Parent: None,
#  ID: 16, Name: Voucher - Dịch Vụ - Thẻ Cào, URL: https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner, Parent: None]

# %%
get_all_categories(main_categories,save_db=True)
# Out:
# Added "Máy tính bảng" to CATEGORY_SET
# Added "Máy đọc sách" to CATEGORY_SET
# Added "Điện thoại Smartphone" to CATEGORY_SET
# Added "Điện thoại bàn" to CATEGORY_SET
# Added "Điện thoại phổ thông" to CATEGORY_SET
# Done
# Added "Máy giặt" to CATEGORY_SET
# Added "Máy lạnh - Máy điều hòa" to CATEGORY_SET
# Added "Máy nước nóng" to CATEGORY_SET
# Added "Máy rửa chén" to CATEGORY_SET
# Added "Máy sấy quần áo" to CATEGORY_SET
# Added "Phụ kiện điện lạnh" to CATEGORY_SET
# Added "Tivi" to CATEGORY_SET
# Added "Tủ lạnh" to CATEGORY_SET
# Added "Tủ đông - Tủ mát" to CATEGORY_SET
# Added "Tủ ướp rượu" to CATEGORY_SET
# Added "Âm thanh & Phụ kiện Tivi" to CATEGORY_SET
# Added "Phụ kiện, linh kiện máy giặt" to CATEGORY_SET
# Added "Phụ kiện, linh kiện máy lạnh" to CATEGORY_SET
# Added "Phụ kiện, linh kiện tủ lạnh" to CATEGORY_SET
# Added "Phụ kiện, linh kiện điện lạnh khác" to CATEGORY_SET
# Done
# Added "Internet Tivi" to CATEGORY_SET
# Added "Smart Tivi - Android Tivi" to CATEGORY_SET
# Added "Tivi 4K" to CATEGORY_SET
# Added "Tivi OLED" to CATEGORY_SET
# Added "Tivi QLED" to CATEGORY_SET
# Added "Tivi cao cấp" to CATEGORY_SET
# Added "Tivi thường (LED)" to CATEGORY_SET
# Done
# Added "Android TV Box, Smart Box" to CATEGORY_SET
# Added "Bộ giải mã âm thanh DAC" to CATEGORY_SET
# Added "Dàn âm thanh" to CATEGORY_SET
# Added "Loa" to CATEGORY_SET
# Added "Micro Karaoke - sân khấu" to CATEGORY_SET
# Added "Máy radio cassette" to CATEGORY_SET
# Added "Phụ kiện Tivi" to CATEGORY_SET
# Added "Phụ kiện âm thanh" to CATEGORY_SET
# Added "Receivers, Amplifier, Mixer" to CATEGORY_SET
# Added "Thiết bị phát Streaming" to CATEGORY_SET
# Added "Đầu CD, DVD, karaoke, Blu-ray" to CATEGORY_SET
# Added "Dàn Karaoke" to CATEGORY_SET
# Added "Dàn âm thanh giải trí tại gia" to CATEGORY_SET
# Done
# Added "Loa Bookshelf" to CATEGORY_SET
# Added "Loa Sub, siêu trầm" to CATEGORY_SET
# Added "Loa karaoke" to CATEGORY_SET
# Added "Loa sân khấu, ngoài trời" to CATEGORY_SET
# Added "Loa thanh, Soundbar" to CATEGORY_SET
# Added "Loa thùng, loa vệ tinh" to CATEGORY_SET
# Added "Loa âm trần - âm tường" to CATEGORY_SET
# Done
# Added "Anten Tivi" to CATEGORY_SET
# Added "Cáp Tivi" to CATEGORY_SET
# Added "Giá treo Tivi" to CATEGORY_SET
# Added "Kính 3D" to CATEGORY_SET
# Added "Điều khiển từ xa Tivi" to CATEGORY_SET
# Added "Đầu thu kỹ thuật số" to CATEGORY_SET
# Done
# Added "Cáp loa, đầu chuyển" to CATEGORY_SET
# Added "Giá treo loa" to CATEGORY_SET
# Added "Phụ kiện âm thanh khác" to CATEGORY_SET
# Done
# Added "Đầu ghi phát CD" to CATEGORY_SET
# Added "Đầu ghi phát DVD, Blu-ray" to CATEGORY_SET
# Added "Đầu phát karaoke" to CATEGORY_SET
# Done
# Done
# Done
# Added "Phụ Kiện Điện Thoại và Máy Tính Bảng" to CATEGORY_SET
# Added "Phụ kiện máy tính và Laptop" to CATEGORY_SET
# Added "Thiết Bị Chơi Game và Phụ Kiện" to CATEGORY_SET
# Added "Thiết Bị Thông Minh và Linh Kiện Điện Tử" to CATEGORY_SET
# Added "Thiết Bị Âm Thanh và Phụ Kiện" to CATEGORY_SET
# Added "Thiết Bị Đeo Thông Minh và Phụ Kiện" to CATEGORY_SET
# Added "Adapter - Củ Sạc" to CATEGORY_SET
# Added "Bao Da - Ốp Lưng" to CATEGORY_SET
# Added "Bàn Phím Rời - Bút Cảm Ứng" to CATEGORY_SET
# Added "Dây Sạc - Dây Cáp" to CATEGORY_SET
# Added "Dây Đeo và Phụ Kiện Trang Trí" to CATEGORY_SET
# Added "Dụng Cụ Sửa Chữa và Vệ Sinh" to CATEGORY_SET
# Added "Giá Đỡ - Chân Đế - Móc Dán" to CATEGORY_SET
# Added "Hộp Đựng - Túi Đựng Phụ Kiện" to CATEGORY_SET
# Added "Linh Kiện Thay Thế" to CATEGORY_SET
# Added "Miếng Dán Màn Hình" to CATEGORY_SET
# Added "Phụ Kiện Chơi Game" to CATEGORY_SET
# Added "Phụ Kiện Chụp Hình" to CATEGORY_SET
# Added "Phụ Kiện Di Động Khác" to CATEGORY_SET
# Added "Pin Sạc Dự Phòng" to CATEGORY_SET
# Added "SIM Điện Thoại" to CATEGORY_SET
# Added "Thẻ Nhớ và Bộ Nhớ Mở Rộng" to CATEGORY_SET
# Added "Túi Bảo Vệ - Túi Chống Nước" to CATEGORY_SET
# Added "Vòng Đeo - Đai Đeo" to CATEGORY_SET
# Added "Adapter Sạc - Củ Sạc Thường" to CATEGORY_SET
# Added "Adapter Sạc - Củ Sạc Xe Hơi" to CATEGORY_SET
# Added "Bộ Adapter Sạc Kèm Cáp Sạc" to CATEGORY_SET
# Added "Đế Sạc Không Dây" to CATEGORY_SET
# Done
# Added "Bao Da - Ốp Lưng Máy Tính Bảng Khác" to CATEGORY_SET
# Added "Bao Da - Ốp Lưng iPad" to CATEGORY_SET
# Added "Bao Da - Ốp Lưng Điện Thoại Asus" to CATEGORY_SET
# Added "Bao Da - Ốp Lưng Điện Thoại Honor" to CATEGORY_SET
# Added "Bao Da - Ốp Lưng Điện Thoại Huawei" to CATEGORY_SET
# Added "Bao Da - Ốp Lưng Điện Thoại Khác" to CATEGORY_SET
# Added "Bao Da - Ốp Lưng Điện Thoại Nokia" to CATEGORY_SET
# Added "Bao Da - Ốp Lưng Điện Thoại Oppo" to CATEGORY_SET
# Added "Bao Da - Ốp Lưng Điện Thoại Samsung" to CATEGORY_SET
# Added "Bao Da - Ốp Lưng Điện Thoại Sony" to CATEGORY_SET
# Added "Bao Da - Ốp Lưng Điện Thoại Vivo" to CATEGORY_SET
# Added "Bao Da - Ốp Lưng Điện Thoại Xiaomi" to CATEGORY_SET
# Added "Bao Da - Ốp Lưng Điện Thoại iPhone" to CATEGORY_SET
# Done
# Added "Bàn Phím Rời - Ốp Tích Hợp Bàn Phím" to CATEGORY_SET
# Added "Bút Cảm Ứng" to CATEGORY_SET
# Done
# Added "Các Loại Cáp Khác" to CATEGORY_SET
# Added "Dây Cáp Sạc Micro USB" to CATEGORY_SET
# Added "Dây Cáp Sạc USB Type-C" to CATEGORY_SET
# Added "Dây Cáp Sạc iPhone, iPad" to CATEGORY_SET
# Added "Dây Cáp Sạc Đa Năng" to CATEGORY_SET
# Done
# Added "Dụng Cụ Sửa Chữa" to CATEGORY_SET
# Added "Dụng Cụ Vệ Sinh" to CATEGORY_SET
# Done
# Added "Giá Đỡ - Chân Đế Gắn Ô Tô, Xe Máy" to CATEGORY_SET
# Added "Giá Đỡ - Chân Đế Thường" to CATEGORY_SET
# Added "Móc Dán Đỡ Điện Thoại" to CATEGORY_SET
# Done
# Added "Linh Kiện Thay Thế Khác" to CATEGORY_SET
# Added "Màn Hình Thay Thế" to CATEGORY_SET
# Added "Pin Thay Thế" to CATEGORY_SET
# Added "Vỏ - Case Thay Thế" to CATEGORY_SET
# Done
# Added "Miếng Dán Màn Hình Điện Thoại" to CATEGORY_SET
# Added "Miếng Dán Thiết Bị Di Động Khác" to CATEGORY_SET
# Done
# Added "Nút Bấm Chơi Game Điện Thoại" to CATEGORY_SET
# Added "Phụ Kiện Chơi Game Điện Thoại Khác" to CATEGORY_SET
# Added "Tay Cầm Chơi Game Điện Thoại" to CATEGORY_SET
# Done
# Added "Gậy Tự Sướng - Selfie" to CATEGORY_SET
# Added "Lens Cho Điện Thoại" to CATEGORY_SET
# Added "Đèn Flash Selfie - Flash Mini" to CATEGORY_SET
# Done
# Added "Pin Sạc Dự Phòng Di Động" to CATEGORY_SET
# Added "Pin Sạc Dự Phòng Ốp Lưng" to CATEGORY_SET
# Done
# Added "SIM Data - SIM 3G / 4G" to CATEGORY_SET
# Added "SIM số" to CATEGORY_SET
# Done
# Added "Thẻ Nhớ Điện Thoại" to CATEGORY_SET
# Added "USB OTG" to CATEGORY_SET
# Done
# Done
# Added "Bàn Di Chuột - Miếng Lót Chuột" to CATEGORY_SET
# Added "Bút Trình Chiếu" to CATEGORY_SET
# Added "Các Loại Cáp Chuyển Đổi" to CATEGORY_SET
# Added "Công Cụ Đồ Họa - Thiết Bị Cảm Ứng" to CATEGORY_SET
# Added "Dụng Cụ Vệ Sinh và Sửa Chữa" to CATEGORY_SET
# Added "Phụ Kiện Laptop" to CATEGORY_SET
# Added "Phụ Kiện Phím Chuột Chơi Game" to CATEGORY_SET
# Added "Phụ Kiện Phím Chuột Văn Phòng" to CATEGORY_SET
# Added "Tai Nghe Máy Tính" to CATEGORY_SET
# Added "Webcam Máy Tính" to CATEGORY_SET
# Added "Bộ Chuyển Đổi Khác" to CATEGORY_SET
# Added "Bộ Chuyển Đổi Tín Hiệu HDMI/VGA/DVI/DP" to CATEGORY_SET
# Added "Cáp HDMI - Displayport" to CATEGORY_SET
# Added "Cáp Song Song - Cáp Máy In - Cáp Serial" to CATEGORY_SET
# Added "Dây Cáp SATA" to CATEGORY_SET
# Added "Dây Cáp Thunderbolt" to CATEGORY_SET
# Added "Dây Cáp Tín Hiệu Khác" to CATEGORY_SET
# Added "Dây Cáp USB" to CATEGORY_SET
# Added "Dây Cáp VGA-DVI" to CATEGORY_SET
# Added "Dây Nguồn" to CATEGORY_SET
# Added "Hub Chuyển Đổi USB Type-C" to CATEGORY_SET
# Added "Hub Chuyển Đổi USB-A" to CATEGORY_SET
# Added "Hub USB" to CATEGORY_SET
# Added "Đầu Đọc Thẻ Nhớ" to CATEGORY_SET
# Done
# Added "Bút Vẽ Đồ Họa Cảm Ứng" to CATEGORY_SET
# Added "Bảng Vẽ Đồ Họa Cảm Ứng" to CATEGORY_SET
# Added "Thiết Bị Cân Bằng Màu" to CATEGORY_SET
# Added "Thiết Bị Đồ Họa và Công Cụ Khác" to CATEGORY_SET
# Done
# Added "Case - Vỏ Ốp Lưng Laptop" to CATEGORY_SET
# Added "Dây Chống Trộm Laptop" to CATEGORY_SET
# Added "Giá Đỡ Laptop" to CATEGORY_SET
# Added "Miếng Phủ Bàn Phím Laptop" to CATEGORY_SET
# Added "Skin và Decal Dán Laptop" to CATEGORY_SET
# Added "Đế Tản Nhiệt Laptop" to CATEGORY_SET
# Done
# Added "Bàn Phím Chơi Game" to CATEGORY_SET
# Added "Bộ Phím Chuột Chơi Game" to CATEGORY_SET
# Added "Chuột Chơi Game" to CATEGORY_SET
# Added "Phụ Kiện Phím Chuột Chơi Game Khác" to CATEGORY_SET
# Done
# Added "Bàn Phím Văn Phòng" to CATEGORY_SET
# Added "Bộ Phím Chuột Văn Phòng" to CATEGORY_SET
# Added "Chuột Văn Phòng" to CATEGORY_SET
# Added "Phụ Kiện Phím Chuột Văn Phòng Khác" to CATEGORY_SET
# Added "Bàn Phím Văn Phòng Có Dây" to CATEGORY_SET
# Added "Bàn Phím Văn Phòng Không Dây" to CATEGORY_SET
# Done
# Added "Chuột Văn Phòng Có Dây" to CATEGORY_SET
# Added "Chuột Văn Phòng Không Dây" to CATEGORY_SET
# Done
# Done
# Added "Tai Nghe Chơi Game" to CATEGORY_SET
# Added "Tai Nghe Văn Phòng - Headset" to CATEGORY_SET
# Done
# Done
# Added "Ghế Gaming" to CATEGORY_SET
# Added "Máy Chơi Game - Console" to CATEGORY_SET
# Added "Phụ Kiện Gaming" to CATEGORY_SET
# Added "Tay Bấm Game - Thiết Bị Điều Khiển" to CATEGORY_SET
# Added "Đĩa Game" to CATEGORY_SET
# Added "Máy Chơi Game Khác" to CATEGORY_SET
# Added "Nintendo" to CATEGORY_SET
# Added "PlayStation" to CATEGORY_SET
# Done
# Done
# Added "Mạch Điện Lập Trình và Linh Kiện Điện Tử" to CATEGORY_SET
# Added "Thiết Bị Số - Thiết Bị Thông Minh" to CATEGORY_SET
# Added "Các Module Tích Hợp" to CATEGORY_SET
# Added "Cảm Biến" to CATEGORY_SET
# Added "Dây, Cáp Nối và Adapter Nguồn" to CATEGORY_SET
# Added "Linh Kiện và Các Phần Cứng Khác" to CATEGORY_SET
# Added "Máy Tính Nhúng - Kit Phát Triển" to CATEGORY_SET
# Added "Phụ Kiện và Dụng Cụ Khác" to CATEGORY_SET
# Added "Thiết Bị Robot" to CATEGORY_SET
# Done
# Added "Kim Từ Điển và Các Loại Máy Thông Dịch" to CATEGORY_SET
# Added "Máy Bộ Đàm" to CATEGORY_SET
# Added "Thiết Bị Nhà Thông Minh" to CATEGORY_SET
# Added "Thiết Bị Định Vị GPS" to CATEGORY_SET
# Added "Đồ Chơi Công Nghệ - Thiết Bị Số và Phụ Kiện Số Khác" to CATEGORY_SET
# Done
# Done
# Added "DAC và Amplifier Di Động" to CATEGORY_SET
# Added "Loa Nghe Nhạc" to CATEGORY_SET
# Added "Micro" to CATEGORY_SET
# Added "Máy Thu và Máy Phát Âm Thanh" to CATEGORY_SET
# Added "Phụ Kiện Âm Thanh" to CATEGORY_SET
# Added "Tai Nghe Bluetooth" to CATEGORY_SET
# Added "Tai Nghe Có Dây" to CATEGORY_SET
# Added "Loa Bluetooth" to CATEGORY_SET
# Added "Loa Bluetooth Vi Tính" to CATEGORY_SET
# Added "Loa Hi-Fi - Audiophiles" to CATEGORY_SET
# Added "Loa Kéo" to CATEGORY_SET
# Added "Loa Trợ Giảng" to CATEGORY_SET
# Added "Loa Vi Tính" to CATEGORY_SET
# Done
# Added "Micro Karaoke Bluetooth" to CATEGORY_SET
# Added "Microphone Di Động" to CATEGORY_SET
# Added "Microphone Vi Tính" to CATEGORY_SET
# Done
# Added "Máy Ghi Âm" to CATEGORY_SET
# Added "Máy Nghe Nhạc" to CATEGORY_SET
# Done
# Added "Bộ Chuyển Đổi Không Dây" to CATEGORY_SET
# Added "Cáp Âm Thanh" to CATEGORY_SET
# Added "Đệm và Nút Tai Nghe" to CATEGORY_SET
# Done
# Added "Tai Nghe Bluetooth Chụp Tai On-Ear" to CATEGORY_SET
# Added "Tai Nghe Bluetooth Chụp Tai Over-Ear" to CATEGORY_SET
# Added "Tai Nghe Bluetooth Nhét Tai" to CATEGORY_SET
# Added "Tai Nghe Bluetooth Đàm Thoại" to CATEGORY_SET
# Added "Tai Nghe True Wireless" to CATEGORY_SET
# Done
# Added "Tai Nghe Có Dây Chụp Tai (On-Ear)" to CATEGORY_SET
# Added "Tai Nghe Có Dây Chụp Tai (Over-Ear)" to CATEGORY_SET
# Added "Tai Nghe Có Dây Nhét Tai" to CATEGORY_SET
# Done
# Done
# Added "Mắt Kính Thông Minh" to CATEGORY_SET
# Added "Phụ Kiện Thiết Bị Đeo Thông Minh" to CATEGORY_SET
# Added "Thiết Bị Thực Tế Ảo VR" to CATEGORY_SET
# Added "Vòng Đeo Thông Minh - Vòng Theo Dõi Vận Động" to CATEGORY_SET
# Added "Đồng Hồ Thông Minh" to CATEGORY_SET
# Added "Adapter Sạc - Cáp Sạc Cho Thiết Bị Đeo" to CATEGORY_SET
# Added "Dây Đeo Thay Thế, Phụ Trợ - Phụ Kiện Khác" to CATEGORY_SET
# Done
# Done
# Done
# Added "Laptop" to CATEGORY_SET
# Added "Linh Kiện Máy Tính - Phụ Kiện Máy Tính" to CATEGORY_SET
# Added "PC - Máy Tính Bộ" to CATEGORY_SET
# Added "Thiết Bị Lưu Trữ" to CATEGORY_SET
# Added "Thiết Bị Mạng" to CATEGORY_SET
# Added "Thiết Bị Văn Phòng - Thiết Bị Ngoại Vi" to CATEGORY_SET
# Added "Laptop 2 trong 1" to CATEGORY_SET
# Added "Laptop Gaming" to CATEGORY_SET
# Added "Laptop Truyền Thống" to CATEGORY_SET
# Added "Macbook" to CATEGORY_SET
# Done
# Added "Bộ Lưu Điện - UPS" to CATEGORY_SET
# Added "Bộ Vi Xử Lý CPU" to CATEGORY_SET
# Added "Card Màn Hình - VGA" to CATEGORY_SET
# Added "Hệ Thống Tản Nhiệt" to CATEGORY_SET
# Added "I/O Port Cards" to CATEGORY_SET
# Added "KVM Switches - Switch HDMI" to CATEGORY_SET
# Added "Linh Kiện Máy Tính Khác" to CATEGORY_SET
# Added "Linh Kiện Thay Thế Cho Laptop" to CATEGORY_SET
# Added "Mainboard - Board Mạch Chủ" to CATEGORY_SET
# Added "Nguồn Máy Tính" to CATEGORY_SET
# Added "RAM Máy Tính" to CATEGORY_SET
# Added "Sound Card - Card Âm Thanh" to CATEGORY_SET
# Added "Thiết Bị Streaming và Capture Cards" to CATEGORY_SET
# Added "Vỏ Case - Thùng Máy" to CATEGORY_SET
# Added "Ổ Đĩa Quang" to CATEGORY_SET
# Added "Keo - Pad Tản Nhiệt" to CATEGORY_SET
# Added "Quạt Tản Nhiệt" to CATEGORY_SET
# Done
# Added "Adapter Sạc Laptop" to CATEGORY_SET
# Added "Bàn Phím Thay Thế Laptop" to CATEGORY_SET
# Added "Linh Kiện Thay Thế Laptop Khác" to CATEGORY_SET
# Added "Pin Thay Thế Laptop" to CATEGORY_SET
# Done
# Added "RAM Desktop" to CATEGORY_SET
# Added "RAM Laptop" to CATEGORY_SET
# Done
# Done
# Added "Mini PC" to CATEGORY_SET
# Added "Máy Tính All in one" to CATEGORY_SET
# Added "Máy Tính Bộ Thương Hiệu" to CATEGORY_SET
# Added "Máy Tính Để Bàn Lắp Ráp" to CATEGORY_SET
# Added "Towers - Máy Chủ - Server" to CATEGORY_SET
# Done
# Added "Case Ổ Cứng- Hộp Đựng HDD Box - Dock Ổ Cứng" to CATEGORY_SET
# Added "Thiết Bị Lưu Trữ Qua Mạng NAS" to CATEGORY_SET
# Added "USB" to CATEGORY_SET
# Added "Đĩa Trắng - Băng Cuộn" to CATEGORY_SET
# Added "Ổ Cứng Di Động" to CATEGORY_SET
# Added "Ổ Cứng Gắn Trong" to CATEGORY_SET
# Added "Ổ Cứng HDD Di Động" to CATEGORY_SET
# Added "Ổ Cứng SSD Di Động" to CATEGORY_SET
# Done
# Added "Ổ Cứng HDD" to CATEGORY_SET
# Added "Ổ Cứng SSD" to CATEGORY_SET
# Done
# Done
# Added "Bộ Chia Mạng - Switch" to CATEGORY_SET
# Added "Bộ Chuyển Đổi - Transceivers" to CATEGORY_SET
# Added "Bộ Kích Sóng Wifi" to CATEGORY_SET
# Added "Bộ Phát Wifi Di Động 3G/4G - Mifi" to CATEGORY_SET
# Added "Card Mạng" to CATEGORY_SET
# Added "Modem ADSL" to CATEGORY_SET
# Added "Mở Rộng Mạng Qua Đường Điện - Powerline Ethernet" to CATEGORY_SET
# Added "Phụ Kiện Thiết Bị Mạng" to CATEGORY_SET
# Added "Thiết Bị Phát Sóng Wifi" to CATEGORY_SET
# Added "Ăng-Ten Mạng" to CATEGORY_SET
# Added "Access Point - Điểm Truy Cập" to CATEGORY_SET
# Added "Router Wifi" to CATEGORY_SET
# Added "USB Wifi" to CATEGORY_SET
# Done
# Done
# Added "Giấy In" to CATEGORY_SET
# Added "Máy In - Photocopy" to CATEGORY_SET
# Added "Màn Hình Máy Tính" to CATEGORY_SET
# Added "Máy Chiếu và Phụ Kiện Máy Chiếu" to CATEGORY_SET
# Added "Máy Chấm Công" to CATEGORY_SET
# Added "Máy Fax" to CATEGORY_SET
# Added "Máy Hủy Tài Liệu" to CATEGORY_SET
# Added "Máy Scan Mã Vạch" to CATEGORY_SET
# Added "Máy Scan Tài Liệu" to CATEGORY_SET
# Added "Máy Đếm Tiền" to CATEGORY_SET
# Added "Mực In và Toner" to CATEGORY_SET
# Added "Phần Mềm Máy Tính" to CATEGORY_SET
# Added "Thiết Bị Truyền Thông Hội Nghị" to CATEGORY_SET
# Added "Giấy In Hóa Đơn - Giấy In Tem" to CATEGORY_SET
# Added "Giấy In Ảnh" to CATEGORY_SET
# Added "Nhãn In" to CATEGORY_SET
# Done
# Added "Linh Kiện và Phụ Kiện Máy In" to CATEGORY_SET
# Added "Máy In Kim" to CATEGORY_SET
# Added "Máy In Laser" to CATEGORY_SET
# Added "Máy In Nhãn, Hóa Đơn" to CATEGORY_SET
# Added "Máy In Phun" to CATEGORY_SET
# Added "Máy In Ảnh" to CATEGORY_SET
# Added "Máy Photocopy" to CATEGORY_SET
# Done
# Added "Màn Hình Di Động" to CATEGORY_SET
# Added "Màn Hình Gaming" to CATEGORY_SET
# Added "Màn Hình Phổ Thông" to CATEGORY_SET
# Added "Màn Hình Đồ Họa" to CATEGORY_SET
# Done
# Added "Màn hình ghép - Màn hình LED" to CATEGORY_SET
# Added "Máy chiếu" to CATEGORY_SET
# Added "Phụ kiện máy chiếu" to CATEGORY_SET
# Done
# Added "Drums và Toner Cho Máy In Laser" to CATEGORY_SET
# Added "Mực In Màu" to CATEGORY_SET
# Done
# Done
# Done
# Added "Balo - Túi Đựng - Bao Da" to CATEGORY_SET
# Added "Camera Giám Sát" to CATEGORY_SET
# Added "Camera Hành Trình - Action Camera và Phụ Kiện" to CATEGORY_SET
# Added "Máy Bay Camera và Phụ Kiện" to CATEGORY_SET
# Added "Máy Ảnh" to CATEGORY_SET
# Added "Phụ Kiện Máy Ảnh, Máy Quay" to CATEGORY_SET
# Added "Thiết Bị Quay Phim" to CATEGORY_SET
# Added "Thiết Bị Ánh Sáng" to CATEGORY_SET
# Added "Ống Kính (Lens)" to CATEGORY_SET
# Added "Ống Kính - Ống Ngắm" to CATEGORY_SET
# Added "Bao Đựng Chống Sốc, Chống Nước" to CATEGORY_SET
# Added "Dây Đeo Máy Ảnh, Máy Quay, Ống Nhòm" to CATEGORY_SET
# Added "Hộp Đựng - Tủ Chống Ẩm" to CATEGORY_SET
# Added "Hộp Đựng Filter" to CATEGORY_SET
# Added "Hộp Đựng Lens" to CATEGORY_SET
# Added "Túi và Hộp Đựng Máy Quay" to CATEGORY_SET
# Added "Túi và Hộp Đựng Máy Ảnh" to CATEGORY_SET
# Added "Túi Đựng Chân Đế Tripod và Monopod" to CATEGORY_SET
# Added "Túi Đựng Máy Ảnh" to CATEGORY_SET
# Done
# Added "Camera IP" to CATEGORY_SET
# Added "Camera Quan Sát Analog" to CATEGORY_SET
# Added "Hệ Thống Camera Giám Sát" to CATEGORY_SET
# Added "Phụ Kiện Camera Giám Sát" to CATEGORY_SET
# Added "Đầu Ghi Hình Camera" to CATEGORY_SET
# Done
# Added "Action Camera" to CATEGORY_SET
# Added "Camera Hành Trình Ô Tô, Xe Máy" to CATEGORY_SET
# Added "Phụ Kiện Camera Hành Trình" to CATEGORY_SET
# Done
# Added "Linh Kiện Thay Thế Máy Bay camera - Drone" to CATEGORY_SET
# Added "Máy Bay Camera - Drone" to CATEGORY_SET
# Added "Phụ Kiện Máy Bay Camera - Drone" to CATEGORY_SET
# Done
# Added "Máy Ảnh Compact - Máy Ảnh Du Lịch" to CATEGORY_SET
# Added "Máy Ảnh DSLR" to CATEGORY_SET
# Added "Máy Ảnh Lấy Liền" to CATEGORY_SET
# Added "Máy Ảnh Mirrorless" to CATEGORY_SET
# Done
# Added "Adapter - Ngàm Chuyển" to CATEGORY_SET
# Added "Chân Máy Ảnh, Monopod, Tripod" to CATEGORY_SET
# Added "Dụng Cụ Vệ Sinh Máy Ảnh" to CATEGORY_SET
# Added "Gimbal" to CATEGORY_SET
# Added "Hộp Chụp Ảnh Sản Phẩm" to CATEGORY_SET
# Added "Kính Lọc - Filter" to CATEGORY_SET
# Added "Lens Hood" to CATEGORY_SET
# Added "Miếng Dán Bảo Vệ Màn Hình Máy Ảnh" to CATEGORY_SET
# Added "Ngàm Gắn Máy Quay Trên Người" to CATEGORY_SET
# Added "Nắp Ống Kính" to CATEGORY_SET
# Added "Phụ Kiện Cho Ống Kính" to CATEGORY_SET
# Added "Phụ Kiện Máy Ảnh, Máy Quay Khác" to CATEGORY_SET
# Added "Pin - Sạc Máy Ảnh, Máy Quay" to CATEGORY_SET
# Added "Thiết Bị Phòng Tối" to CATEGORY_SET
# Added "Thẻ Nhớ Máy Ảnh" to CATEGORY_SET
# Added "Túi Hút Ẩm Cho Máy Ảnh, Máy Quay" to CATEGORY_SET
# Added "Điều Khiển Từ Xa" to CATEGORY_SET
# Added "Thẻ Nhớ CF" to CATEGORY_SET
# Added "Thẻ Nhớ Máy Ảnh Khác" to CATEGORY_SET
# Added "Thẻ Nhớ SD" to CATEGORY_SET
# Done
# Done
# Added "Micro Cho Máy Quay" to CATEGORY_SET
# Added "Máy Quay Phim" to CATEGORY_SET
# Added "Máy Quay Phim Chuyên Dụng" to CATEGORY_SET
# Added "Phụ Kiện Máy Quay Khác" to CATEGORY_SET
# Done
# Added "Máy Đo Sáng và Phụ Kiện" to CATEGORY_SET
# Added "Thiết Bị Phản Sáng và Phụ Kiện" to CATEGORY_SET
# Added "Đèn Chiếu Sáng Studio" to CATEGORY_SET
# Added "Đèn Flash và Phụ Kiện" to CATEGORY_SET
# Done
# Added "Ống Kính Máy Quay Phim" to CATEGORY_SET
# Added "Ống Kính Máy Ảnh" to CATEGORY_SET
# Done
# Added "Kính Hiển Vi" to CATEGORY_SET
# Added "Kính Viễn Vọng - Kính Thiên Văn" to CATEGORY_SET
# Added "Phụ Kiện Ống Kính, Ống Ngắm" to CATEGORY_SET
# Added "Ống Ngắm" to CATEGORY_SET
# Added "Ống Nhòm" to CATEGORY_SET
# Done
# Done
# Added "Thiết bị gia đình" to CATEGORY_SET
# Added "Đồ dùng nhà bếp" to CATEGORY_SET
# Added "Bàn ủi, bàn là" to CATEGORY_SET
# Added "Cây Nước Nóng Lạnh" to CATEGORY_SET
# Added "Máy hút bụi" to CATEGORY_SET
# Added "Máy hút ẩm" to CATEGORY_SET
# Added "Máy lọc không khí" to CATEGORY_SET
# Added "Máy lọc nước" to CATEGORY_SET
# Added "Máy may, thêu, vắt sổ" to CATEGORY_SET
# Added "Máy sấy tay" to CATEGORY_SET
# Added "Máy tạo ẩm" to CATEGORY_SET
# Added "Quạt điện" to CATEGORY_SET
# Added "Thiết bị sưởi ấm" to CATEGORY_SET
# Added "Bàn ủi hơi nước" to CATEGORY_SET
# Added "Bàn ủi hơi nước đứng" to CATEGORY_SET
# Added "Bàn ủi khô" to CATEGORY_SET
# Done
# Added "Hút bụi công nghiệp" to CATEGORY_SET
# Added "Hút bụi cầm tay" to CATEGORY_SET
# Added "Hút bụi gia đình" to CATEGORY_SET
# Added "Phụ kiện máy hút bụi" to CATEGORY_SET
# Added "Robot hút bụi" to CATEGORY_SET
# Done
# Added "Máy lọc nước có điện" to CATEGORY_SET
# Added "Máy lọc nước không điện" to CATEGORY_SET
# Added "Phụ kiện máy lọc nước" to CATEGORY_SET
# Added "Đầu lọc nước tại vòi" to CATEGORY_SET
# Done
# Added "Máy may cơ" to CATEGORY_SET
# Added "Máy may điện tử" to CATEGORY_SET
# Added "Máy thêu" to CATEGORY_SET
# Added "Máy vắt sổ" to CATEGORY_SET
# Added "Phụ kiện máy may, thêu, vắt sổ" to CATEGORY_SET
# Done
# Added "Quạt bàn" to CATEGORY_SET
# Added "Quạt hút, quạt thông gió" to CATEGORY_SET
# Added "Quạt hơi nước, phun sương" to CATEGORY_SET
# Added "Quạt hộp" to CATEGORY_SET
# Added "Quạt lửng" to CATEGORY_SET
# Added "Quạt mini" to CATEGORY_SET
# Added "Quạt sạc" to CATEGORY_SET
# Added "Quạt tháp" to CATEGORY_SET
# Added "Quạt treo tường" to CATEGORY_SET
# Added "Quạt trần" to CATEGORY_SET
# Added "Quạt Đứng" to CATEGORY_SET
# Done
# Added "Máy sưởi" to CATEGORY_SET
# Added "Quạt sưởi" to CATEGORY_SET
# Added "Đèn sưởi" to CATEGORY_SET
# Done
# Done
# Added "Bình thủy điện" to CATEGORY_SET
# Added "Bình đun siêu tốc" to CATEGORY_SET
# Added "Bếp các loại" to CATEGORY_SET
# Added "Lò nướng điện" to CATEGORY_SET
# Added "Lò vi sóng" to CATEGORY_SET
# Added "Máy cắt thịt đông lạnh" to CATEGORY_SET
# Added "Máy hàn miệng túi" to CATEGORY_SET
# Added "Máy hút chân không" to CATEGORY_SET
# Added "Máy hút khói, khử mùi" to CATEGORY_SET
# Added "Máy làm bánh" to CATEGORY_SET
# Added "Máy làm kem" to CATEGORY_SET
# Added "Máy làm mì sợi" to CATEGORY_SET
# Added "Máy làm sữa chua" to CATEGORY_SET
# Added "Máy làm sữa đậu nành" to CATEGORY_SET
# Added "Máy làm tỏi đen" to CATEGORY_SET
# Added "Máy pha cà phê" to CATEGORY_SET
# Added "Máy sấy chén" to CATEGORY_SET
# Added "Máy sấy thực phẩm" to CATEGORY_SET
# Added "Máy xay, máy ép" to CATEGORY_SET
# Added "Máy đánh trứng" to CATEGORY_SET
# Added "Nồi điện các loại" to CATEGORY_SET
# Added "Siêu sắc thuốc" to CATEGORY_SET
# Added "Vỉ nướng điện" to CATEGORY_SET
# Added "Đồ dùng nhà bếp khác" to CATEGORY_SET
# Added "Bếp gas" to CATEGORY_SET
# Added "Bếp hồng ngoại" to CATEGORY_SET
# Added "Bếp lẩu, nướng" to CATEGORY_SET
# Added "Bếp điện kết hợp" to CATEGORY_SET
# Added "Bếp điện quang" to CATEGORY_SET
# Added "Bếp điện từ" to CATEGORY_SET
# Added "Bếp gas du lịch - bếp gas đơn" to CATEGORY_SET
# Added "Bếp gas dương" to CATEGORY_SET
# Added "Bếp gas âm" to CATEGORY_SET
# Added "Phụ kiện bếp gas" to CATEGORY_SET
# Done
# Added "Bếp hồng ngoại đôi" to CATEGORY_SET
# Added "Bếp hồng ngoại đơn" to CATEGORY_SET
# Done
# Added "Bếp điện từ đôi" to CATEGORY_SET
# Added "Bếp điện từ đơn" to CATEGORY_SET
# Done
# Done
# Added "Lò nướng bánh mì sandwich" to CATEGORY_SET
# Added "Lò nướng thùng" to CATEGORY_SET
# Added "Lò nướng thủy tinh" to CATEGORY_SET
# Added "Lò nướng âm tủ" to CATEGORY_SET
# Done
# Added "Lò vi sóng có nướng" to CATEGORY_SET
# Added "Lò vi sóng cơ" to CATEGORY_SET
# Added "Lò vi sóng hơi nước" to CATEGORY_SET
# Added "Lò vi sóng âm" to CATEGORY_SET
# Added "Lò vi sóng điện tử" to CATEGORY_SET
# Done
# Added "Máy pha cà phê chuyên dụng" to CATEGORY_SET
# Added "Máy pha cà phê gia đình" to CATEGORY_SET
# Added "Máy xay cà phê" to CATEGORY_SET
# Added "Phụ kiện máy pha cà phê" to CATEGORY_SET
# Added "Viên nén cà phê" to CATEGORY_SET
# Done
# Added "Máy vắt cam" to CATEGORY_SET
# Added "Máy xay cầm tay" to CATEGORY_SET
# Added "Máy xay cắt đa năng" to CATEGORY_SET
# Added "Máy xay sinh tố" to CATEGORY_SET
# Added "Máy xay thịt" to CATEGORY_SET
# Added "Máy xay ép đa năng" to CATEGORY_SET
# Added "Máy ép trái cây" to CATEGORY_SET
# Added "Máy xay sinh tố công nghiệp" to CATEGORY_SET
# Added "Máy xay sinh tố gia đình" to CATEGORY_SET
# Done
# Done
# Added "Nồi chiên" to CATEGORY_SET
# Added "Nồi cơm điện" to CATEGORY_SET
# Added "Nồi hấp" to CATEGORY_SET
# Added "Nồi lẩu điện" to CATEGORY_SET
# Added "Nồi tiềm" to CATEGORY_SET
# Added "Nồi tiềm, nồi nấu cháo" to CATEGORY_SET
# Added "Nồi áp suất" to CATEGORY_SET
# Added "Nồi đa năng" to CATEGORY_SET
# Added "Nồi cơm dung tích lớn" to CATEGORY_SET
# Added "Nồi cơm nắp gài" to CATEGORY_SET
# Added "Nồi cơm nắp rời" to CATEGORY_SET
# Added "Nồi cơm điện tử" to CATEGORY_SET
# Done
# Done
# Done
# Done
# Added "Bảo vệ nhà cửa" to CATEGORY_SET
# Added "Dụng cụ diệt chuột, côn trùng" to CATEGORY_SET
# Added "Dụng cụ nhà bếp" to CATEGORY_SET
# Added "Dụng cụ vệ sinh" to CATEGORY_SET
# Added "Hoa tươi và cây cảnh" to CATEGORY_SET
# Added "Ngoài trời & sân vườn" to CATEGORY_SET
# Added "Nhạc cụ" to CATEGORY_SET
# Added "Nội thất" to CATEGORY_SET
# Added "Phụ kiện giặt ủi" to CATEGORY_SET
# Added "Pin và dụng cụ sạc pin" to CATEGORY_SET
# Added "Sửa chữa nhà cửa" to CATEGORY_SET
# Added "Thiết bị điều khiển thông minh" to CATEGORY_SET
# Added "Trang trí nhà cửa" to CATEGORY_SET
# Added "Vật phẩm phong thủy" to CATEGORY_SET
# Added "Đèn & thiết bị chiếu sáng" to CATEGORY_SET
# Added "Đồ dùng phòng ngủ" to CATEGORY_SET
# Added "Đồ dùng phòng ăn" to CATEGORY_SET
# Added "Đồ dùng và thiết bị nhà tắm" to CATEGORY_SET
# Added "Đồ thờ cúng" to CATEGORY_SET
# Added "Ổ cắm điện" to CATEGORY_SET
# Added "Ổn áp, biến áp" to CATEGORY_SET
# Added "Bảo vệ nhà cửa khác" to CATEGORY_SET
# Added "Chuông báo" to CATEGORY_SET
# Added "Khóa cửa thông minh" to CATEGORY_SET
# Added "Ổ khóa" to CATEGORY_SET
# Done
# Added "Dụng cụ diệt côn trùng khác" to CATEGORY_SET
# Added "Vợt muỗi" to CATEGORY_SET
# Added "Đèn diệt côn trùng" to CATEGORY_SET
# Done
# Added "Bếp nướng, vỉ nướng" to CATEGORY_SET
# Added "Dao và phụ kiện" to CATEGORY_SET
# Added "Dụng cụ chứa đựng thực phẩm" to CATEGORY_SET
# Added "Dụng cụ làm bánh" to CATEGORY_SET
# Added "Dụng cụ nấu ăn" to CATEGORY_SET
# Added "Kéo nhà bếp" to CATEGORY_SET
# Added "Kệ nhà bếp" to CATEGORY_SET
# Added "Phụ kiện nhà bếp" to CATEGORY_SET
# Added "Thớt nhà bếp" to CATEGORY_SET
# Added "Đồ dùng một lần" to CATEGORY_SET
# Added "Ấm nước các loại" to CATEGORY_SET
# Added "Bếp cồn" to CATEGORY_SET
# Added "Bếp nướng" to CATEGORY_SET
# Added "Cồn" to CATEGORY_SET
# Added "Dụng cụ mồi lửa" to CATEGORY_SET
# Added "Than" to CATEGORY_SET
# Added "Vỉ nướng" to CATEGORY_SET
# Done
# Added "Bộ dao" to CATEGORY_SET
# Added "Dao chặt" to CATEGORY_SET
# Added "Dao cắt bánh" to CATEGORY_SET
# Added "Dao cắt thịt đông lạnh" to CATEGORY_SET
# Added "Dao gọt củ, quả" to CATEGORY_SET
# Added "Dao khác" to CATEGORY_SET
# Added "Dao làm cá" to CATEGORY_SET
# Added "Dao lạng thịt, cắt lát" to CATEGORY_SET
# Added "Dao thái" to CATEGORY_SET
# Added "Dao tỉa" to CATEGORY_SET
# Added "Dụng cụ Cắt-Gọt-Bào" to CATEGORY_SET
# Added "Dụng cụ mài dao" to CATEGORY_SET
# Added "Giá dắt dao" to CATEGORY_SET
# Done
# Added "Cà men, hộp đựng cơm" to CATEGORY_SET
# Added "Hũ, lọ đựng gia vị" to CATEGORY_SET
# Added "Hộp hâm nóng" to CATEGORY_SET
# Added "Hộp đựng thực phẩm" to CATEGORY_SET
# Added "Khay" to CATEGORY_SET
# Added "Thau, rổ" to CATEGORY_SET
# Added "Thùng đá" to CATEGORY_SET
# Added "Thùng đựng gạo" to CATEGORY_SET
# Added "Thùng đựng thực phẩm" to CATEGORY_SET
# Added "Túi đựng thực phẩm" to CATEGORY_SET
# Done
# Added "Cân nhà bếp" to CATEGORY_SET
# Added "Cây lăn bột" to CATEGORY_SET
# Added "Cây đánh trứng" to CATEGORY_SET
# Added "Dụng  cụ làm bánh khác" to CATEGORY_SET
# Added "Dụng cụ đo lường" to CATEGORY_SET
# Added "Khay nướng bánh" to CATEGORY_SET
# Added "Khuôn làm bánh" to CATEGORY_SET
# Done
# Added "Bộ nồi" to CATEGORY_SET
# Added "Chảo, chảo chống dính" to CATEGORY_SET
# Added "Nồi lẩu" to CATEGORY_SET
# Added "Nồi ủ" to CATEGORY_SET
# Added "Nồi, quánh" to CATEGORY_SET
# Added "Xửng hấp" to CATEGORY_SET
# Done
# Added "Kéo cắt gà" to CATEGORY_SET
# Added "Kéo đa năng" to CATEGORY_SET
# Done
# Added "Khay úp chén bát" to CATEGORY_SET
# Added "Kệ chén bát" to CATEGORY_SET
# Added "Kệ gia vị" to CATEGORY_SET
# Added "Kệ nhà bếp khác" to CATEGORY_SET
# Added "Kệ rượu nhỏ" to CATEGORY_SET
# Added "Kệ để lò vi sóng" to CATEGORY_SET
# Added "Kệ để nồi chảo" to CATEGORY_SET
# Done
# Added "Chậu rửa chén bát" to CATEGORY_SET
# Added "Dụng cụ mở nắp" to CATEGORY_SET
# Added "Dụng cụ xay, giã" to CATEGORY_SET
# Added "Dụng cụ ép trái cây, vắt cam" to CATEGORY_SET
# Added "Giấy thấm dầu mỡ" to CATEGORY_SET
# Added "Găng tay nhà bếp" to CATEGORY_SET
# Added "Khay, khuôn làm đá" to CATEGORY_SET
# Added "Khuôn làm kem" to CATEGORY_SET
# Added "Khăn giấy ăn" to CATEGORY_SET
# Added "Khăn lót bàn ăn" to CATEGORY_SET
# Added "Kẹp càng cua" to CATEGORY_SET
# Added "Kẹp gắp" to CATEGORY_SET
# Added "Màng bọc thực phẩm" to CATEGORY_SET
# Added "Màng nhôm, giấy bạc" to CATEGORY_SET
# Added "Nhấc nồi" to CATEGORY_SET
# Added "Phụ kiện nhà bếp khác" to CATEGORY_SET
# Added "Rế, lót nồi" to CATEGORY_SET
# Added "Thiết bị làm giá" to CATEGORY_SET
# Added "Tô nhúng bánh tráng" to CATEGORY_SET
# Added "Túi đựng hộp cơm" to CATEGORY_SET
# Added "Tạp dề" to CATEGORY_SET
# Added "Vá, sạn, vợt" to CATEGORY_SET
# Added "Vòi rửa chén bát" to CATEGORY_SET
# Added "Xe đi chợ" to CATEGORY_SET
# Added "Ống đũa" to CATEGORY_SET
# Added "Dụng cụ xay giã khác" to CATEGORY_SET
# Added "Dụng cụ xay tiêu" to CATEGORY_SET
# Added "Máy xay thịt bằng tay" to CATEGORY_SET
# Done
# Done
# Added "Bao tay dùng một lần" to CATEGORY_SET
# Added "Chén đĩa dùng một lần" to CATEGORY_SET
# Added "Ly dùng một lần" to CATEGORY_SET
# Added "Muỗng, đũa, nĩa, dao dùng một lần" to CATEGORY_SET
# Added "Đồ dùng một lần khác" to CATEGORY_SET
# Added "Ống hút" to CATEGORY_SET
# Done
# Done
# Added "Bàn chải, dụng cụ thông tắc, cọ rửa" to CATEGORY_SET
# Added "Cây lau kiếng" to CATEGORY_SET
# Added "Găng tay" to CATEGORY_SET
# Added "Khăn lau đa năng" to CATEGORY_SET
# Added "Miếng rửa chén, chà nồi" to CATEGORY_SET
# Added "Thùng rác" to CATEGORY_SET
# Added "Túi đựng rác" to CATEGORY_SET
# Added "Đồ hốt rác, ky rác" to CATEGORY_SET
# Done
# Added "Chậu hoa" to CATEGORY_SET
# Added "Cây chậu treo" to CATEGORY_SET
# Added "Cây ngoài trời" to CATEGORY_SET
# Added "Cây nội thất - Văn phòng" to CATEGORY_SET
# Added "Cây để bàn" to CATEGORY_SET
# Added "Hoa bình - Lọ" to CATEGORY_SET
# Added "Hoa bó" to CATEGORY_SET
# Added "Hoa chia buồn" to CATEGORY_SET
# Added "Hoa chậu treo" to CATEGORY_SET
# Added "Hoa giỏ - Lẵng - Kệ" to CATEGORY_SET
# Added "Hoa hộp" to CATEGORY_SET
# Added "Phụ kiện cây" to CATEGORY_SET
# Added "Phụ kiện hoa" to CATEGORY_SET
# Added "Tiểu cảnh" to CATEGORY_SET
# Added "Móc treo cây cảnh" to CATEGORY_SET
# Added "Phụ kiện trang trí cây khác" to CATEGORY_SET
# Added "Đĩa lót chậu" to CATEGORY_SET
# Added "Đất trồng cây" to CATEGORY_SET
# Done
# Added "Bình - Lọ cắm hoa" to CATEGORY_SET
# Added "Phụ kiện hoa khác" to CATEGORY_SET
# Done
# Done
# Added "Bình tưới nước" to CATEGORY_SET
# Added "Bể bơi ngoài trời" to CATEGORY_SET
# Added "Bộ hẹn giờ tưới cây" to CATEGORY_SET
# Added "Chậu trồng cây" to CATEGORY_SET
# Added "Dụng cụ làm vườn" to CATEGORY_SET
# Added "Dụng cụ ngoài trời khác" to CATEGORY_SET
# Added "Hạt giống" to CATEGORY_SET
# Added "Kệ trang trí cây" to CATEGORY_SET
# Added "Lưới che nắng" to CATEGORY_SET
# Added "Mái hiên" to CATEGORY_SET
# Added "Máy bơm" to CATEGORY_SET
# Added "Máy cắt cỏ" to CATEGORY_SET
# Added "Máy xịt rửa và phụ kiện" to CATEGORY_SET
# Added "Ngoại thất sân vườn" to CATEGORY_SET
# Added "Nội thất ngoài trời" to CATEGORY_SET
# Added "Phân bón" to CATEGORY_SET
# Added "Tấm trải đa năng" to CATEGORY_SET
# Added "Vòi nước và phụ kiện tưới cây" to CATEGORY_SET
# Added "Áo mưa, ô dù và phụ kiện" to CATEGORY_SET
# Added "Đồ trang trí ngoài trời" to CATEGORY_SET
# Added "Bể bơi" to CATEGORY_SET
# Added "Phụ kiện bể bơi" to CATEGORY_SET
# Done
# Added "Chậu cây tự dưỡng" to CATEGORY_SET
# Added "Phụ kiện trồng cây" to CATEGORY_SET
# Done
# Added "Máy xịt rửa" to CATEGORY_SET
# Added "Phụ kiện máy xịt rửa" to CATEGORY_SET
# Done
# Added "Bàn ngoài trời" to CATEGORY_SET
# Added "Bộ bàn ghế ngoài trời" to CATEGORY_SET
# Added "Ghế ngoài trời" to CATEGORY_SET
# Added "Ngoại thất sân vườn khác" to CATEGORY_SET
# Added "Xích đu" to CATEGORY_SET
# Done
# Added "Phụ kiện tưới cây" to CATEGORY_SET
# Added "Vòi nước tưới cây" to CATEGORY_SET
# Done
# Added "Bao, túi bọc giày" to CATEGORY_SET
# Added "Giày, ủng đi mưa" to CATEGORY_SET
# Added "Phụ kiện đi mưa khác" to CATEGORY_SET
# Added "Áo mưa" to CATEGORY_SET
# Added "Ô dù" to CATEGORY_SET
# Done
# Done
# Added "Amply guitar điện, bass, gỗ" to CATEGORY_SET
# Added "Dây đàn" to CATEGORY_SET
# Added "Giá đỡ" to CATEGORY_SET
# Added "Hộp đàn - Bao đàn" to CATEGORY_SET
# Added "Kèn - Sáo" to CATEGORY_SET
# Added "Máy lên dây, tuner" to CATEGORY_SET
# Added "Nhạc cụ dân tộc - Gizheng - Echu" to CATEGORY_SET
# Added "Phơ Guitar" to CATEGORY_SET
# Added "Phụ kiện khác" to CATEGORY_SET
# Added "Phụ kiện trống" to CATEGORY_SET
# Added "Phụ kiện đàn ukulele - guitarlele" to CATEGORY_SET
# Added "Pickup đàn Guitar điện" to CATEGORY_SET
# Added "Pickup đàn acoustics" to CATEGORY_SET
# Added "Trống - Drum" to CATEGORY_SET
# Added "Trống Lục Lạc Gõ Bo - Tambourine" to CATEGORY_SET
# Added "Đàn Kalimba" to CATEGORY_SET
# Added "Đàn guitar bass" to CATEGORY_SET
# Added "Đàn guitar thùng, gỗ" to CATEGORY_SET
# Added "Đàn guitar điện" to CATEGORY_SET
# Added "Đàn organ - keyboard" to CATEGORY_SET
# Added "Đàn piano Upright" to CATEGORY_SET
# Added "Đàn piano điện" to CATEGORY_SET
# Added "Đàn ukulele - guitarlele" to CATEGORY_SET
# Added "Đàn violin - viola" to CATEGORY_SET
# Added "Sáo - Tiêu" to CATEGORY_SET
# Added "Đàn bầu" to CATEGORY_SET
# Added "Đàn nguyệt" to CATEGORY_SET
# Added "Đàn nhị" to CATEGORY_SET
# Added "Đàn tranh" to CATEGORY_SET
# Added "Đàn đáy - Cồng chiêng" to CATEGORY_SET
# Done
# Added "Capo" to CATEGORY_SET
# Added "Chân micro" to CATEGORY_SET
# Added "Dây cáp" to CATEGORY_SET
# Added "Dây đeo Guitar" to CATEGORY_SET
# Added "Jack" to CATEGORY_SET
# Added "Phụ kiện nhạc cụ khác" to CATEGORY_SET
# Done
# Done
# Added "Nội thất khác" to CATEGORY_SET
# Added "Nội thất phòng học, làm việc" to CATEGORY_SET
# Added "Nội thất phòng khách" to CATEGORY_SET
# Added "Nội thất phòng ngủ" to CATEGORY_SET
# Added "Nội thất phòng ăn" to CATEGORY_SET
# Added "Nội thất trẻ em" to CATEGORY_SET
# Added "Bàn học sinh" to CATEGORY_SET
# Added "Bàn làm việc" to CATEGORY_SET
# Added "Bàn vi tính" to CATEGORY_SET
# Added "Ghế làm việc" to CATEGORY_SET
# Added "Nội thất phòng học, làm việc khác" to CATEGORY_SET
# Added "Tủ, kệ sách" to CATEGORY_SET
# Done
# Added "Bàn sofa/salon" to CATEGORY_SET
# Added "Bộ sofa/salon" to CATEGORY_SET
# Added "Ghế lười" to CATEGORY_SET
# Added "Ghế sofa/salon" to CATEGORY_SET
# Added "Ghế thư giãn" to CATEGORY_SET
# Added "Ghế đôn" to CATEGORY_SET
# Added "Kệ giày" to CATEGORY_SET
# Added "Kệ tivi" to CATEGORY_SET
# Added "Kệ trang trí" to CATEGORY_SET
# Added "Kệ để báo" to CATEGORY_SET
# Added "Nội thất phòng khách khác" to CATEGORY_SET
# Added "Rèm, màn cửa" to CATEGORY_SET
# Added "Thảm trang trí" to CATEGORY_SET
# Added "Tủ giày" to CATEGORY_SET
# Added "Vách ngăn trang trí" to CATEGORY_SET
# Done
# Added "Bàn trang điểm" to CATEGORY_SET
# Added "Cửa gỗ" to CATEGORY_SET
# Added "Ghế cuối giường" to CATEGORY_SET
# Added "Ghế hơi" to CATEGORY_SET
# Added "Ghế trang điểm" to CATEGORY_SET
# Added "Ghế xếp" to CATEGORY_SET
# Added "Giường ngủ" to CATEGORY_SET
# Added "Gương" to CATEGORY_SET
# Added "Két sắt" to CATEGORY_SET
# Added "Nội thất phòng ngủ khác" to CATEGORY_SET
# Added "Tủ quần áo" to CATEGORY_SET
# Added "Tủ đầu giường" to CATEGORY_SET
# Added "Tủ, thùng, hộp, khay đựng đồ" to CATEGORY_SET
# Added "Tủ gỗ" to CATEGORY_SET
# Added "Tủ khác" to CATEGORY_SET
# Added "Tủ nhựa" to CATEGORY_SET
# Added "Tủ nhựa ghép" to CATEGORY_SET
# Added "Tủ vải" to CATEGORY_SET
# Done
# Done
# Added "Bàn cafe" to CATEGORY_SET
# Added "Bàn ăn" to CATEGORY_SET
# Added "Bộ bàn ghế phòng ăn" to CATEGORY_SET
# Added "Ghế bar" to CATEGORY_SET
# Added "Ghế phòng ăn" to CATEGORY_SET
# Added "Nội thất phòng ăn khác" to CATEGORY_SET
# Added "Quầy bar" to CATEGORY_SET
# Added "Tủ & kệ rượu" to CATEGORY_SET
# Added "Tủ bếp" to CATEGORY_SET
# Done
# Added "Bàn trẻ em" to CATEGORY_SET
# Added "Ghế trẻ em" to CATEGORY_SET
# Added "Giường ngủ trẻ em" to CATEGORY_SET
# Added "Nội thất trẻ em khác" to CATEGORY_SET
# Added "Thùng đựng đồ chơi" to CATEGORY_SET
# Added "Giường tầng" to CATEGORY_SET
# Added "Giường đơn" to CATEGORY_SET
# Done
# Done
# Done
# Added "Bàn để ủi" to CATEGORY_SET
# Added "Cây lăn bụi" to CATEGORY_SET
# Added "Giỏ đựng quần áo" to CATEGORY_SET
# Added "Phụ kiện giặt ủi khác" to CATEGORY_SET
# Added "Túi giặt" to CATEGORY_SET
# Added "Áo bọc bàn để ủi" to CATEGORY_SET
# Done
# Added "Máy sạc pin" to CATEGORY_SET
# Added "Pin sạc" to CATEGORY_SET
# Added "Pin tiểu, pin sạc" to CATEGORY_SET
# Done
# Added "Búa các loại" to CATEGORY_SET
# Added "Bảo hộ lao động" to CATEGORY_SET
# Added "Bộ dụng cụ đa năng" to CATEGORY_SET
# Added "Bộ lục giác" to CATEGORY_SET
# Added "Cây lăn - Súng phun sơn" to CATEGORY_SET
# Added "Cưa gỗ, cưa sắt" to CATEGORY_SET
# Added "Cảo" to CATEGORY_SET
# Added "Cờ lê, mỏ lết" to CATEGORY_SET
# Added "Dũa các loại" to CATEGORY_SET
# Added "Dụng cụ sửa chữa khác" to CATEGORY_SET
# Added "Kềm các loại" to CATEGORY_SET
# Added "Máy chà nhám, đánh bóng" to CATEGORY_SET
# Added "Máy cưa" to CATEGORY_SET
# Added "Máy hàn" to CATEGORY_SET
# Added "Máy khoan, mũi khoan" to CATEGORY_SET
# Added "Máy mài, máy cắt" to CATEGORY_SET
# Added "Máy phun xịt rửa" to CATEGORY_SET
# Added "Máy phát điện" to CATEGORY_SET
# Added "Máy thổi" to CATEGORY_SET
# Added "Máy vặn vít, tua vít" to CATEGORY_SET
# Added "Máy, mũi soi, phay gỗ" to CATEGORY_SET
# Added "Palang, ròng rọc, con đội" to CATEGORY_SET
# Added "Ron, miếng dán khe cửa, chân cửa" to CATEGORY_SET
# Added "Súng bắn keo" to CATEGORY_SET
# Added "Sơn, dầu mỡ, hóa chất" to CATEGORY_SET
# Added "Thang nhôm" to CATEGORY_SET
# Added "Thùng đồ nghề, túi công cụ" to CATEGORY_SET
# Added "Thước đo các loại" to CATEGORY_SET
# Added "Xe đẩy hàng" to CATEGORY_SET
# Added "Đá cắt, que hàn, lưỡi cưa" to CATEGORY_SET
# Added "Máy khoan" to CATEGORY_SET
# Added "Mũi khoan" to CATEGORY_SET
# Done
# Added "Máy cắt" to CATEGORY_SET
# Added "Máy mài" to CATEGORY_SET
# Done
# Added "Máy vặn vít" to CATEGORY_SET
# Added "Tua vít" to CATEGORY_SET
# Done
# Added "Máy soi, phay gỗ" to CATEGORY_SET
# Added "Mũi khoét gỗ" to CATEGORY_SET
# Done
# Added "Dầu mỡ" to CATEGORY_SET
# Added "Hóa chất" to CATEGORY_SET
# Added "Sơn" to CATEGORY_SET
# Done
# Added "Thùng đồ nghề" to CATEGORY_SET
# Added "Túi công cụ" to CATEGORY_SET
# Done
# Added "Lưỡi cưa" to CATEGORY_SET
# Added "Que hàn" to CATEGORY_SET
# Added "Đá cắt" to CATEGORY_SET
# Done
# Done
# Added "Bình hoa" to CATEGORY_SET
# Added "Decal" to CATEGORY_SET
# Added "Giấy dán kính" to CATEGORY_SET
# Added "Giấy dán tường" to CATEGORY_SET
# Added "Hoa trang trí" to CATEGORY_SET
# Added "Móc treo, móc dán tường" to CATEGORY_SET
# Added "Nến trang trí" to CATEGORY_SET
# Added "Phù điêu" to CATEGORY_SET
# Added "Tháp đồng hồ" to CATEGORY_SET
# Added "Trang trí nhà cửa khác" to CATEGORY_SET
# Added "Tranh trang trí" to CATEGORY_SET
# Added "Tranh treo tường" to CATEGORY_SET
# Added "Tranh đồng hồ" to CATEGORY_SET
# Added "Vật phẩm trang trí" to CATEGORY_SET
# Added "Đồ đốt tinh dầu" to CATEGORY_SET
# Added "Đồng hồ treo tường" to CATEGORY_SET
# Added "Đồng hồ để bàn" to CATEGORY_SET
# Added "3D" to CATEGORY_SET
# Added "Các nước" to CATEGORY_SET
# Added "Decal dán bếp" to CATEGORY_SET
# Added "Decal khác" to CATEGORY_SET
# Added "Dạ quang" to CATEGORY_SET
# Added "Hoa, lá, cỏ cây" to CATEGORY_SET
# Added "Hoạt hình" to CATEGORY_SET
# Added "Khung tranh ảnh" to CATEGORY_SET
# Added "Phong cảnh" to CATEGORY_SET
# Added "Phong thủy" to CATEGORY_SET
# Added "Thông điệp chữ" to CATEGORY_SET
# Added "Trang trí Tết" to CATEGORY_SET
# Added "Trang trí chân tường" to CATEGORY_SET
# Added "Trang trí noel" to CATEGORY_SET
# Added "Tình yêu" to CATEGORY_SET
# Added "Đo chiều cao" to CATEGORY_SET
# Added "Động vật" to CATEGORY_SET
# Done
# Added "Giấy dán kính 3D" to CATEGORY_SET
# Added "Giấy dán kính hoa, lá, cỏ cây" to CATEGORY_SET
# Added "Giấy dán kính hoạt hình" to CATEGORY_SET
# Added "Giấy dán kính họa tiết" to CATEGORY_SET
# Added "Giấy dán kính khác" to CATEGORY_SET
# Added "Giấy dán kính mờ" to CATEGORY_SET
# Added "Giấy dán kính thông điệp chữ" to CATEGORY_SET
# Added "Giấy dán kính động vật" to CATEGORY_SET
# Done
# Added "Giấy dán tường 3D" to CATEGORY_SET
# Added "Giấy dán tường caro, kẻ sọc" to CATEGORY_SET
# Added "Giấy dán tường các nước" to CATEGORY_SET
# Added "Giấy dán tường giả gỗ, giả gạch" to CATEGORY_SET
# Added "Giấy dán tường hoa, lá, cỏ cây" to CATEGORY_SET
# Added "Giấy dán tường hoạt hình" to CATEGORY_SET
# Added "Giấy dán tường họa tiết" to CATEGORY_SET
# Added "Giấy dán tường khác" to CATEGORY_SET
# Added "Giấy dán tường màu trơn" to CATEGORY_SET
# Added "Giấy dán tường phong cảnh" to CATEGORY_SET
# Added "Giấy dán tường thông điệp chữ" to CATEGORY_SET
# Added "Giấy dán tường tình yêu" to CATEGORY_SET
# Added "Giấy dán tường động vật" to CATEGORY_SET
# Done
# Added "Các loại tranh khác" to CATEGORY_SET
# Added "Tranh canvas" to CATEGORY_SET
# Added "Tranh gỗ khảm ngọc" to CATEGORY_SET
# Added "Tranh gỗ đục chạm" to CATEGORY_SET
# Added "Tranh phong thủy" to CATEGORY_SET
# Added "Tranh sơn dầu" to CATEGORY_SET
# Added "Tranh sơn mài" to CATEGORY_SET
# Added "Tranh thêu" to CATEGORY_SET
# Added "Tranh thư pháp" to CATEGORY_SET
# Added "Tranh đính đá" to CATEGORY_SET
# Added "Tranh đồng" to CATEGORY_SET
# Done
# Added "Mô hình trang trí" to CATEGORY_SET
# Added "Tượng trang trí" to CATEGORY_SET
# Added "Vật phẩm trang trí khác" to CATEGORY_SET
# Done
# Added "Đồng hồ treo tường cơ" to CATEGORY_SET
# Added "Đồng hồ treo tường pin" to CATEGORY_SET
# Added "Đồng hồ treo tường điện" to CATEGORY_SET
# Done
# Done
# Added "Bắp cải phong thủy" to CATEGORY_SET
# Added "Bộ 12 con giáp" to CATEGORY_SET
# Added "Cá phong thủy" to CATEGORY_SET
# Added "Cây phong thủy" to CATEGORY_SET
# Added "Gương bát quái, La bàn" to CATEGORY_SET
# Added "Kỳ Lân" to CATEGORY_SET
# Added "Linh vật phong thủy khác" to CATEGORY_SET
# Added "Long Quy" to CATEGORY_SET
# Added "Mèo thần tài" to CATEGORY_SET
# Added "Ngựa phong thủy" to CATEGORY_SET
# Added "Phượng Hoàng" to CATEGORY_SET
# Added "Quy" to CATEGORY_SET
# Added "Rồng phong thủy" to CATEGORY_SET
# Added "Tam đa (Phước Lộc Thọ)" to CATEGORY_SET
# Added "Thiềm thừ phong thủy" to CATEGORY_SET
# Added "Thác nước phong thủy" to CATEGORY_SET
# Added "Tiền hoa mai, đồng xu, tiền cổ" to CATEGORY_SET
# Added "Tượng Phật" to CATEGORY_SET
# Added "Tỳ hưu phong thủy" to CATEGORY_SET
# Added "Vật phẩm phong thủy khác" to CATEGORY_SET
# Added "Đá quý, đá phong thủy" to CATEGORY_SET
# Done
# Added "Bóng đèn" to CATEGORY_SET
# Added "Linh kiện đèn" to CATEGORY_SET
# Added "Đèn bàn" to CATEGORY_SET
# Added "Đèn chùm" to CATEGORY_SET
# Added "Đèn cảm ứng" to CATEGORY_SET
# Added "Đèn khác" to CATEGORY_SET
# Added "Đèn ngoài trời" to CATEGORY_SET
# Added "Đèn ngủ" to CATEGORY_SET
# Added "Đèn pin" to CATEGORY_SET
# Added "Đèn sạc" to CATEGORY_SET
# Added "Đèn trang trí" to CATEGORY_SET
# Added "Đèn trần" to CATEGORY_SET
# Added "Đèn đọc sách" to CATEGORY_SET
# Added "Đèn đứng" to CATEGORY_SET
# Done
# Added "Bộ ga, ra, drap" to CATEGORY_SET
# Added "Chiếu" to CATEGORY_SET
# Added "Chăn, mền và phụ kiện" to CATEGORY_SET
# Added "Gối, ruột gối, vỏ gối" to CATEGORY_SET
# Added "Mùng, màn ngủ" to CATEGORY_SET
# Added "Nệm và phụ kiện" to CATEGORY_SET
# Added "Phụ kiện phòng ngủ" to CATEGORY_SET
# Added "Võng" to CATEGORY_SET
# Added "Đệm ngồi" to CATEGORY_SET
# Added "Bộ chăn ga, ra, drap" to CATEGORY_SET
# Added "Bộ ga, ra, drap không chăn" to CATEGORY_SET
# Done
# Added "Chăn chần gòn" to CATEGORY_SET
# Added "Chăn, mền" to CATEGORY_SET
# Added "Ruột mền" to CATEGORY_SET
# Added "Vỏ mền" to CATEGORY_SET
# Done
# Added "Gối nằm" to CATEGORY_SET
# Added "Gối tựa cổ" to CATEGORY_SET
# Added "Gối vuông trang trí" to CATEGORY_SET
# Added "Gối ôm" to CATEGORY_SET
# Added "Ruột gối nằm" to CATEGORY_SET
# Added "Ruột gối ôm" to CATEGORY_SET
# Added "Vỏ gối nằm" to CATEGORY_SET
# Added "Vỏ gối vuông trang trí" to CATEGORY_SET
# Added "Vỏ gối ôm" to CATEGORY_SET
# Done
# Added "Nệm bông ép" to CATEGORY_SET
# Added "Nệm cao su" to CATEGORY_SET
# Added "Nệm foam" to CATEGORY_SET
# Added "Nệm hơi" to CATEGORY_SET
# Added "Nệm khác" to CATEGORY_SET
# Added "Nệm lò xo" to CATEGORY_SET
# Added "Nệm nước" to CATEGORY_SET
# Added "Topper nệm" to CATEGORY_SET
# Added "Tấm bảo vệ nệm" to CATEGORY_SET
# Done
# Added "Bộ võng xếp" to CATEGORY_SET
# Added "Khung võng" to CATEGORY_SET
# Added "Võng lưới" to CATEGORY_SET
# Done
# Done
# Added "Bình lọc, lõi lọc, thiết bị lọc nước" to CATEGORY_SET
# Added "Bình nước, bình giữ nhiệt" to CATEGORY_SET
# Added "Bình, ca đựng nước" to CATEGORY_SET
# Added "Bình, ly uống cà phê và phụ kiện" to CATEGORY_SET
# Added "Bình, ly uống trà và phụ kiện" to CATEGORY_SET
# Added "Bộ Bình Ly" to CATEGORY_SET
# Added "Dụng cụ pha chế" to CATEGORY_SET
# Added "Khăn trải bàn" to CATEGORY_SET
# Added "Ly, cốc" to CATEGORY_SET
# Added "Phụ kiện phòng ăn" to CATEGORY_SET
# Added "Tô, chén, dĩa" to CATEGORY_SET
# Added "Đũa, muỗng, nĩa" to CATEGORY_SET
# Added "Bình lọc" to CATEGORY_SET
# Added "Lõi lọc" to CATEGORY_SET
# Added "Thiết bị lọc" to CATEGORY_SET
# Done
# Added "Bình giữ nhiệt" to CATEGORY_SET
# Added "Bình thủy giữ nhiệt không điện" to CATEGORY_SET
# Added "Ly giữ nhiệt" to CATEGORY_SET
# Done
# Added "Bình đựng nước" to CATEGORY_SET
# Added "Ca đựng nước" to CATEGORY_SET
# Done
# Added "Bình pha cà phê" to CATEGORY_SET
# Added "Giấy lọc cà phê" to CATEGORY_SET
# Added "Ly cà phê" to CATEGORY_SET
# Added "Phin cà phê" to CATEGORY_SET
# Added "Phụ kiện uống cà phê khác" to CATEGORY_SET
# Done
# Added "Bình lọc trà" to CATEGORY_SET
# Added "Bộ bình trà" to CATEGORY_SET
# Added "Hũ đựng trà" to CATEGORY_SET
# Added "Khay trà" to CATEGORY_SET
# Added "Ly uống trà" to CATEGORY_SET
# Added "Phụ kiện uống trà khác" to CATEGORY_SET
# Done
# Added "Bình lắc" to CATEGORY_SET
# Added "Bình xịt kem" to CATEGORY_SET
# Added "Dụng cụ pha chế khác" to CATEGORY_SET
# Added "Máy bào đá" to CATEGORY_SET
# Added "Tháp bia" to CATEGORY_SET
# Done
# Added "Khay úp ly" to CATEGORY_SET
# Added "Ly bia" to CATEGORY_SET
# Added "Ly kem" to CATEGORY_SET
# Added "Ly rượu, cocktail" to CATEGORY_SET
# Added "Ly uống nước" to CATEGORY_SET
# Added "Ly, cốc và phụ kiện khác" to CATEGORY_SET
# Added "Tách trà, cà phê" to CATEGORY_SET
# Added "Đế lót ly" to CATEGORY_SET
# Done
# Added "Gạt tàn" to CATEGORY_SET
# Added "Hộp khăn giấy" to CATEGORY_SET
# Added "Khay mứt" to CATEGORY_SET
# Added "Phụ kiện phòng ăn khác" to CATEGORY_SET
# Done
# Added "Bộ tô chén dĩa" to CATEGORY_SET
# Added "Tô, chén, dĩa lẻ" to CATEGORY_SET
# Done
# Done
# Added "Bộ lau nhà" to CATEGORY_SET
# Added "Ca múc nước" to CATEGORY_SET
# Added "Chổi, cây lau nhà" to CATEGORY_SET
# Added "Cước cọ rửa" to CATEGORY_SET
# Added "Dép nhà tắm" to CATEGORY_SET
# Added "Ghế kê chân" to CATEGORY_SET
# Added "Giá, kệ phơi quần áo" to CATEGORY_SET
# Added "Khăn" to CATEGORY_SET
# Added "Khăn lau, cước cọ rửa" to CATEGORY_SET
# Added "Kệ nhà tắm" to CATEGORY_SET
# Added "Miếng lót bồn cầu" to CATEGORY_SET
# Added "Máy lau hơi nước" to CATEGORY_SET
# Added "Móc treo, kẹp quần áo" to CATEGORY_SET
# Added "Phụ kiện nhà tắm khác" to CATEGORY_SET
# Added "Rèm phòng tắm" to CATEGORY_SET
# Added "Thau, chậu" to CATEGORY_SET
# Added "Thiết bị phòng tắm" to CATEGORY_SET
# Added "Thảm chùi chân" to CATEGORY_SET
# Added "Xô lau nhà" to CATEGORY_SET
# Added "Áo choàng tắm" to CATEGORY_SET
# Added "Khăn mặt" to CATEGORY_SET
# Added "Khăn tay" to CATEGORY_SET
# Added "Khăn tắm" to CATEGORY_SET
# Added "Mũ quấn tóc" to CATEGORY_SET
# Done
# Added "Kệ nhà tắm khác" to CATEGORY_SET
# Added "Kệ xà phòng, kem đánh răng" to CATEGORY_SET
# Added "Kệ, máng treo quần áo" to CATEGORY_SET
# Added "Kệ, tủ gương nhà tắm" to CATEGORY_SET
# Done
# Added "Bidet" to CATEGORY_SET
# Added "Bồn cầu" to CATEGORY_SET
# Added "Lavabo" to CATEGORY_SET
# Added "Thiết bị phòng tắm khác" to CATEGORY_SET
# Added "Thoát sàn" to CATEGORY_SET
# Added "Vòi lavabo" to CATEGORY_SET
# Added "Vòi nước" to CATEGORY_SET
# Added "Vòi sen" to CATEGORY_SET
# Added "Vòi xịt vệ sinh" to CATEGORY_SET
# Done
# Done
# Added "Bàn thờ" to CATEGORY_SET
# Added "Bát hương, bát nhang" to CATEGORY_SET
# Added "Bộ đồ thờ" to CATEGORY_SET
# Added "Chuông, mõ" to CATEGORY_SET
# Added "Cốc nước thờ" to CATEGORY_SET
# Added "Hương, nhang" to CATEGORY_SET
# Added "Hạc đồng" to CATEGORY_SET
# Added "Lư trầm" to CATEGORY_SET
# Added "Miếng chắn khói" to CATEGORY_SET
# Added "Nến thờ" to CATEGORY_SET
# Added "Phụ kiện thờ cúng" to CATEGORY_SET
# Added "Ông Địa - Ông Thần Tài" to CATEGORY_SET
# Added "Đèn thờ dầu" to CATEGORY_SET
# Added "Đèn thờ điện" to CATEGORY_SET
# Added "Đỉnh đồng" to CATEGORY_SET
# Done
# Done
# Added "Bánh kẹo" to CATEGORY_SET
# Added "Bộ quà tặng" to CATEGORY_SET
# Added "Chăm sóc nhà cửa" to CATEGORY_SET
# Added "Chăm sóc thú cưng" to CATEGORY_SET
# Added "Gia vị" to CATEGORY_SET
# Added "Thực phẩm" to CATEGORY_SET
# Added "Thực phẩm bảo vệ sức khỏe" to CATEGORY_SET
# Added "Thực phẩm bổ dưỡng" to CATEGORY_SET
# Added "Thực phẩm cao cấp" to CATEGORY_SET
# Added "Thực phẩm chay" to CATEGORY_SET
# Added "Thực phẩm hữu cơ" to CATEGORY_SET
# Added "Đồ uống - Giải khát" to CATEGORY_SET
# Added "Đồ uống - Pha chế" to CATEGORY_SET
# Added "Bánh" to CATEGORY_SET
# Added "Bánh kẹo khác" to CATEGORY_SET
# Added "Chocolate" to CATEGORY_SET
# Added "Kẹo" to CATEGORY_SET
# Added "Snack" to CATEGORY_SET
# Done
# Added "Giặt giũ & Chăm sóc quần áo" to CATEGORY_SET
# Added "Khăn giấy" to CATEGORY_SET
# Added "Vệ sinh nhà bếp" to CATEGORY_SET
# Added "Vệ sinh nhà cửa" to CATEGORY_SET
# Added "Vệ sinh nhà tắm" to CATEGORY_SET
# Added "Bộ sản phẩm chăm sóc quần áo" to CATEGORY_SET
# Added "Bột giặt" to CATEGORY_SET
# Added "Nước giặt" to CATEGORY_SET
# Added "Nước xả vải" to CATEGORY_SET
# Added "Nước ủi quần áo" to CATEGORY_SET
# Added "Sản phẩm chăm sóc áo quần khác" to CATEGORY_SET
# Done
# Added "Khăn giấy khô" to CATEGORY_SET
# Done
# ...
# Added "Travel" to CATEGORY_SET
# Done
# Added "Art & Design" to CATEGORY_SET
# Added "Bút - Viết" to CATEGORY_SET
# Added "Máy tính" to CATEGORY_SET
# Added "Sổ tay" to CATEGORY_SET
# Added "Văn Phòng Phẩm Khác" to CATEGORY_SET
# Done
# Done
# Added "Adapter - Củ sạc" to CATEGORY_SET
# Added "Bao da - Ốp lưng" to CATEGORY_SET
# Added "Bàn phím" to CATEGORY_SET
# Added "Chuột" to CATEGORY_SET
# Added "Dây sạc, Dây cáp" to CATEGORY_SET
# Added "Gậy tự sướng/ Selfie" to CATEGORY_SET
# Added "Linh kiện điện thoại" to CATEGORY_SET
# Added "Loa nghe nhạc" to CATEGORY_SET
# Added "Loa vi tính" to CATEGORY_SET
# Added "Microphone" to CATEGORY_SET
# Added "Màn hình & miếng dán màn hình" to CATEGORY_SET
# Added "Máy ghi âm" to CATEGORY_SET
# Added "Máy nghe nhạc" to CATEGORY_SET
# Added "Pin sạc dự phòng" to CATEGORY_SET
# Added "Portable Amplifier" to CATEGORY_SET
# Added "Sim điện thoại" to CATEGORY_SET
# Added "Tai nghe" to CATEGORY_SET
# Added "Thiết bị Game" to CATEGORY_SET
# Added "Thiết bị số - Khác" to CATEGORY_SET
# Added "Thiết bị thông minh" to CATEGORY_SET
# Added "Thẻ nhớ điện thoại" to CATEGORY_SET
# Added "Đầu đọc thẻ nhớ" to CATEGORY_SET
# Added "Đồ chơi công nghệ" to CATEGORY_SET
# Added "Thiết bị nhà thông minh" to CATEGORY_SET
# Added "Thiết bị thông minh khác" to CATEGORY_SET
# Added "Thiết bị thực tế ảo" to CATEGORY_SET
# Added "Vòng theo dõi vận động" to CATEGORY_SET
# Added "Đồng hồ thông minh" to CATEGORY_SET
# Done
# Done
# Added "Các môn thể dục và yoga" to CATEGORY_SET
# Added "Giày & trang phục thể thao" to CATEGORY_SET
# Added "Hoạt động dã ngoại" to CATEGORY_SET
# Added "Phụ kiện thể thao, dã ngoại" to CATEGORY_SET
# Added "Đấm bốc & Võ thuật" to CATEGORY_SET
# Done
# Added "Phụ kiện thời trang khác" to CATEGORY_SET
# Added "Thời trang nam" to CATEGORY_SET
# Added "Thời trang nữ" to CATEGORY_SET
# Added "Trang Sức" to CATEGORY_SET
# Added "Túi xách và Phụ kiện" to CATEGORY_SET
# Added "Giày nam" to CATEGORY_SET
# Added "Mắt kính" to CATEGORY_SET
# Added "Phụ kiện nam" to CATEGORY_SET
# Added "Trang phục bơi nam" to CATEGORY_SET
# Added "Trang phục nam" to CATEGORY_SET
# Added "Túi xách, ví nam" to CATEGORY_SET
# Added "Tất Nam" to CATEGORY_SET
# Added "Đồ ngủ, mặc nhà, đồ lót nam" to CATEGORY_SET
# Added "Đồng hồ nam" to CATEGORY_SET
# Done
# Added "Giày dép nữ" to CATEGORY_SET
# Added "Mắt kính nữ" to CATEGORY_SET
# Added "Trang phục bơi nữ" to CATEGORY_SET
# Added "Trang phục nữ" to CATEGORY_SET
# Added "Túi thời trang nữ" to CATEGORY_SET
# Added "Tất Nữ" to CATEGORY_SET
# Added "Đồ ngủ, đồ mặc nhà, nội y" to CATEGORY_SET
# Added "Đồng hồ nữ" to CATEGORY_SET
# Done
# Added "Phụ kiện" to CATEGORY_SET
# Added "Túi xách & Balo" to CATEGORY_SET
# Added "Vali" to CATEGORY_SET
# Done
# Done
# Added "Amply" to CATEGORY_SET
# Added "Phụ kiện loa âm thanh" to CATEGORY_SET
# Added "Tivi box, smart box" to CATEGORY_SET
# Added "Đầu CD, DVD, karaoke" to CATEGORY_SET
# Done
# Added "Phụ kiện xe đạp" to CATEGORY_SET
# Done
# Added "Phụ kiện điện gia dụng" to CATEGORY_SET
# Added "Thiết bị nhà bếp" to CATEGORY_SET
# Added "Điện lạnh" to CATEGORY_SET
# Added "Bình các loại" to CATEGORY_SET
# Added "Các loại máy khác" to CATEGORY_SET
# Added "Lò nướng, vỉ nướng, lò vi sóng" to CATEGORY_SET
# Added "Nồi điện" to CATEGORY_SET
# Done
# Done
# Done
# Added "Quà lưu niệm" to CATEGORY_SET
# Added "Sách tiếng Việt" to CATEGORY_SET
# Added "Văn phòng phẩm" to CATEGORY_SET
# Added "Album - Khung Hình" to CATEGORY_SET
# Added "Bookmark" to CATEGORY_SET
# Added "Gương mini" to CATEGORY_SET
# Added "Hộp Nhạc" to CATEGORY_SET
# Added "Hộp quà - Túi quà" to CATEGORY_SET
# Added "Kẹp Ảnh Gỗ" to CATEGORY_SET
# Added "Ly - Cốc" to CATEGORY_SET
# Added "Móc Khóa - Phụ Kiện Trang Trí" to CATEGORY_SET
# Added "Phụ kiện - Vật liệu trang trí" to CATEGORY_SET
# Added "Quà tặng trang sức" to CATEGORY_SET
# Added "Quà tặng trang trí khác" to CATEGORY_SET
# Added "Quả Cầu Tuyết" to CATEGORY_SET
# Added "Sticker - Decal trang trí" to CATEGORY_SET
# Added "Thiệp - Bưu ảnh" to CATEGORY_SET
# Added "Thú Nhồi Bông" to CATEGORY_SET
# Added "Tượng" to CATEGORY_SET
# Added "Đồng Hồ Cát" to CATEGORY_SET
# Done
# Added "Sách Bà mẹ - Em bé" to CATEGORY_SET
# Added "Sách Chính Trị - Pháp Lý" to CATEGORY_SET
# Added "Sách Công Nghệ Thông Tin" to CATEGORY_SET
# Added "Sách Giáo Khoa - Giáo Trình" to CATEGORY_SET
# Added "Sách Học Ngoại Ngữ" to CATEGORY_SET
# Added "Sách Khoa Học - Kỹ Thuật" to CATEGORY_SET
# Added "Sách Kiến Thức Tổng Hợp" to CATEGORY_SET
# Added "Sách Lịch sử" to CATEGORY_SET
# Added "Sách Nông - Lâm - Ngư Nghiệp" to CATEGORY_SET
# Added "Sách Tham Khảo" to CATEGORY_SET
# Added "Sách Thường Thức - Gia Đình" to CATEGORY_SET
# Added "Sách Tâm lý - Giới tính" to CATEGORY_SET
# Added "Sách Tôn Giáo - Tâm Linh" to CATEGORY_SET
# Added "Sách Văn Hóa - Địa Lý - Du Lịch" to CATEGORY_SET
# Added "Sách Y Học" to CATEGORY_SET
# Added "Sách kinh tế" to CATEGORY_SET
# Added "Sách kỹ năng sống" to CATEGORY_SET
# Added "Sách thiếu nhi" to CATEGORY_SET
# Added "Sách văn học" to CATEGORY_SET
# Added "Thể Dục - Thể Thao" to CATEGORY_SET
# Added "Truyện Tranh, Manga, Comic" to CATEGORY_SET
# Added "Tạp Chí - Catalogue" to CATEGORY_SET
# Added "Từ Điển" to CATEGORY_SET
# Added "Điện Ảnh - Nhạc - Họa" to CATEGORY_SET
# Added "Sách Dinh Dưỡng - Sức Khỏe Cho Bé" to CATEGORY_SET
# Added "Sách Kiến Thức - Kỹ Năng Cho Trẻ" to CATEGORY_SET
# Added "Sách Làm Cha Mẹ" to CATEGORY_SET
# Added "Sách Thai Giáo" to CATEGORY_SET
# Done
# Added "Luật - Văn Bản Luật" to CATEGORY_SET
# Added "Lý Luận Chính Trị" to CATEGORY_SET
# Done
# Added "Lập Trình" to CATEGORY_SET
# Added "Thiết Kế - Đồ Họa" to CATEGORY_SET
# Added "Tin Học Văn Phòng" to CATEGORY_SET
# Done
# Added "Giáo Trình Đại Học - Cao Đẳng" to CATEGORY_SET
# Added "Sách Giáo Khoa Cấp 1" to CATEGORY_SET
# Added "Sách Giáo Khoa Cấp 2" to CATEGORY_SET
# Added "Sách Giáo Khoa Cấp 3" to CATEGORY_SET
# Done
# Added "Ngoại Ngữ Khác" to CATEGORY_SET
# Added "Sách Học Tiếng Anh" to CATEGORY_SET
# Added "Sách Học Tiếng Hoa" to CATEGORY_SET
# Added "Sách Học Tiếng Hàn" to CATEGORY_SET
# Added "Sách Học Tiếng Nhật" to CATEGORY_SET
# Done
# Added "Kiến Thức Bách Khoa" to CATEGORY_SET
# Added "Lĩnh vực khác" to CATEGORY_SET
# Added "Sách Chiêm Tinh - Horoscope" to CATEGORY_SET
# Added "Sách Phong Thủy - Kinh Dịch" to CATEGORY_SET
# Added "Sách giáo dục" to CATEGORY_SET
# Added "Triết Học" to CATEGORY_SET
# Done
# Added "Lịch Sử Thế Giới" to CATEGORY_SET
# Added "Lịch Sử Việt Nam" to CATEGORY_SET
# Done
# Added "Sách Luyện Thi Đại Học - Cao Đẳng" to CATEGORY_SET
# Added "Sách chuyên đề" to CATEGORY_SET
# Added "Sách tham khảo cấp I" to CATEGORY_SET
# Added "Sách tham khảo cấp II" to CATEGORY_SET
# Added "Sách tham khảo cấp III" to CATEGORY_SET
# Added "Thẻ luyện thi" to CATEGORY_SET
# Done
# Added "Chăm sóc sức khỏe" to CATEGORY_SET
# Added "May - Thêu - Thời Trang" to CATEGORY_SET
# Added "Sách Làm Đẹp" to CATEGORY_SET
# Added "Sách Nấu ăn" to CATEGORY_SET
# Done
# Added "Sách Hôn Nhân - Giới Tính" to CATEGORY_SET
# Added "Sách Tâm Lý Tuổi Teen" to CATEGORY_SET
# Done
# Added "Sách Danh Nhân" to CATEGORY_SET
# Added "Sách Phong Tục - Tập Quán" to CATEGORY_SET
# Added "Sách Địa Danh - Du Lịch" to CATEGORY_SET
# Done
# Added "Bài học kinh doanh" to CATEGORY_SET
# Added "Sách Marketing - Bán hàng" to CATEGORY_SET
# Added "Sách doanh nhân" to CATEGORY_SET
# Added "Sách khởi nghiệp" to CATEGORY_SET
# Added "Sách kinh tế học" to CATEGORY_SET
# Added "Sách kỹ năng làm việc" to CATEGORY_SET
# Added "Sách quản trị nhân lực" to CATEGORY_SET
# Added "Sách quản trị, lãnh đạo" to CATEGORY_SET
# Added "Sách tài chính, kế toán" to CATEGORY_SET
# Added "Sách tài chính, tiền tệ" to CATEGORY_SET
# Done
# Added "Sách hướng nghiệp - Kỹ năng mềm" to CATEGORY_SET
# Added "Sách nghệ thuật sống đẹp" to CATEGORY_SET
# Added "Sách tư duy - Kỹ năng sống" to CATEGORY_SET
# Done
# Added "Kiến thức - Bách khoa" to CATEGORY_SET
# Added "Truyện cổ tích" to CATEGORY_SET
# Added "Truyện kể cho bé" to CATEGORY_SET
# Added "Truyện tranh Ehon" to CATEGORY_SET
# Added "Truyện tranh thiếu nhi" to CATEGORY_SET
# Added "Tô màu - Luyện chữ" to CATEGORY_SET
# Added "Văn học thiếu nhi" to CATEGORY_SET
# Added "Đạo đức - Kỹ năng sống" to CATEGORY_SET
# Done
# Added "Ca dao - Tục ngữ" to CATEGORY_SET
# Added "Du ký" to CATEGORY_SET
# Added "Light novel" to CATEGORY_SET
# Added "Phê Bình - Lý Luận Văn Học" to CATEGORY_SET
# Added "Phóng sự - Ký sự - Bút ký" to CATEGORY_SET
# Added "Sách ảnh" to CATEGORY_SET
# Added "Thơ" to CATEGORY_SET
# Added "Tiểu Thuyết" to CATEGORY_SET
# Added "Tiểu sử - Hồi ký" to CATEGORY_SET
# Added "Tranh Truyện" to CATEGORY_SET
# Added "Truyện Giả tưởng - Huyền Bí - Phiêu Lưu" to CATEGORY_SET
# Added "Truyện cười" to CATEGORY_SET
# Added "Truyện cổ tích - Ngụ ngôn" to CATEGORY_SET
# Added "Truyện dài" to CATEGORY_SET
# Added "Truyện kinh dị" to CATEGORY_SET
# Added "Truyện kiếm hiệp" to CATEGORY_SET
# Added "Truyện ngôn tình" to CATEGORY_SET
# Added "Truyện ngắn - Tản văn - Tạp Văn" to CATEGORY_SET
# Added "Truyện trinh thám" to CATEGORY_SET
# Added "Truyện đam mỹ" to CATEGORY_SET
# Added "Tác phẩm kinh điển" to CATEGORY_SET
# Done
# Added "Từ Điển Ngôn Ngữ Khác" to CATEGORY_SET
# Added "Từ Điển Tiếng Anh" to CATEGORY_SET
# Added "Từ Điển Tiếng Hàn" to CATEGORY_SET
# Added "Từ Điển Tiếng Nhật" to CATEGORY_SET
# Added "Từ Điển Tiếng Pháp" to CATEGORY_SET
# Added "Từ Điển Tiếng Trung" to CATEGORY_SET
# Added "Từ Điển Tiếng Việt" to CATEGORY_SET
# Done
# Added "Mỹ Thuật - Kiến Trúc" to CATEGORY_SET
# Added "Sách Tô Màu Dành Cho Người Lớn" to CATEGORY_SET
# Added "Âm Nhạc - Điện Ảnh" to CATEGORY_SET
# Done
# Done
# Added "Balo Học Sinh - Cặp học sinh" to CATEGORY_SET
# Added "Bút - Viết các loại" to CATEGORY_SET
# Added "Bút Chì Màu - Bút Lông Màu - Sáp Màu" to CATEGORY_SET
# Added "Bút Kỹ Thuật" to CATEGORY_SET
# Added "Dụng Cụ Học Sinh" to CATEGORY_SET
# Added "Dụng Cụ Văn Phòng" to CATEGORY_SET
# Added "Flashcards" to CATEGORY_SET
# Added "Lịch" to CATEGORY_SET
# Added "Máy Tính Điện Tử" to CATEGORY_SET
# Added "Sản phẩm về giấy" to CATEGORY_SET
# Added "Sổ Tay Các Loại" to CATEGORY_SET
# Added "Thiết Bị Giáo Dục Trường Học" to CATEGORY_SET
# Added "Thiết bị văn phòng" to CATEGORY_SET
# Added "Tập vở các loại" to CATEGORY_SET
# Added "Văn Hóa Phẩm" to CATEGORY_SET
# Added "Bút bi - Ruột bút bi" to CATEGORY_SET
# Added "Bút cao cấp" to CATEGORY_SET
# Added "Bút chuyên dụng" to CATEGORY_SET
# Added "Bút chì - Ruột bút chì" to CATEGORY_SET
# Added "Bút dạ quang" to CATEGORY_SET
# Added "Bút gel - Bút nước" to CATEGORY_SET
# Added "Bút lông bảng" to CATEGORY_SET
# Added "Bút lông kim" to CATEGORY_SET
# Added "Bút mực - Bút máy" to CATEGORY_SET
# Added "Bút sơn" to CATEGORY_SET
# Added "Bút viết học sinh" to CATEGORY_SET
# Added "Bút viết thư pháp" to CATEGORY_SET
# Added "Bút vẽ kỹ thuật" to CATEGORY_SET
# Added "Bút vẽ trên vải" to CATEGORY_SET
# Added "Bút xóa - Xóa kéo" to CATEGORY_SET
# Done
# Added "Bút Lông Màu" to CATEGORY_SET
# Added "Chì Màu - Sáp Màu" to CATEGORY_SET
# Added "Cọ Vẽ - Màu Nước" to CATEGORY_SET
# Added "Sáp - Chì màu cho bé" to CATEGORY_SET
# Done
# Added "Bao Tập - Bao Sách" to CATEGORY_SET
# Added "Bóp Viết - Hộp Bút" to CATEGORY_SET
# Added "Bảng Viết" to CATEGORY_SET
# Added "Compa" to CATEGORY_SET
# Added "Dụng cụ học sinh khác" to CATEGORY_SET
# Added "Gọt bút chì - Gôm Tẩy" to CATEGORY_SET
# Added "Sáp nặn" to CATEGORY_SET
# Added "Sản Phẩm Giáo Dục Điện Tử" to CATEGORY_SET
# Added "Thước kẻ - Compa" to CATEGORY_SET
# Added "Tập Học Sinh" to CATEGORY_SET
# Added "Vỉ - Bộ Dụng Cụ Học Sinh" to CATEGORY_SET
# Added "Từ Điển Điện Tử" to CATEGORY_SET
# Done
# Done
# Added "Bút Viết Văn Phòng" to CATEGORY_SET
# Added "Băng Keo - Keo Hồ - Cắt Keo" to CATEGORY_SET
# Added "Con dấu" to CATEGORY_SET
# Added "Cắm Viết Các Loại" to CATEGORY_SET
# Added "Dụng cụ văn phòng khác" to CATEGORY_SET
# Added "File Hồ Sơ - Bìa Hồ Sơ" to CATEGORY_SET
# Added "Kéo - Dao Rọc Giấy" to CATEGORY_SET
# Added "Kẹp Bướm - Dây Đeo" to CATEGORY_SET
# Added "Kệ Đựng Hồ Sơ" to CATEGORY_SET
# Added "Máy Hủy Giấy" to CATEGORY_SET
# Added "Máy tính văn phòng" to CATEGORY_SET
# Added "Mực Các Loại" to CATEGORY_SET
# Added "Phấn - Bảng viết - Lau bảng" to CATEGORY_SET
# Added "Đồ Bấm - Kim Kẹp" to CATEGORY_SET
# Added "Bút Bi" to CATEGORY_SET
# Added "Bút Cao Cấp" to CATEGORY_SET
# Added "Bút Dạ Quang - Bút Gel - Bút Kim Tuyến" to CATEGORY_SET
# Added "Bút Lông Bảng - Bút Lông Dầu - Bút Ghi Đĩa" to CATEGORY_SET
# Added "Bút Lông Kim" to CATEGORY_SET
# Added "Bút Sơn - Bút Kỹ Thuật - Bút Tạo Hình" to CATEGORY_SET
# Added "Ruột Bút" to CATEGORY_SET
# Done
# Added "Máy Tính Cầm Tay" to CATEGORY_SET
# Done
# Added "Bấm Lỗ" to CATEGORY_SET
# Added "Bấm kim - kim bấm" to CATEGORY_SET
# Added "Kim Kẹp" to CATEGORY_SET
# Done
# Done
# Added "Flashcard Luyện Thi Tiếng Anh" to CATEGORY_SET
# Added "Flashcard Tiếng Anh" to CATEGORY_SET
# Added "Flashcard Tiếng Hàn" to CATEGORY_SET
# Added "Flashcard Tiếng Nhật" to CATEGORY_SET
# Added "Flashcard Tiếng Trung" to CATEGORY_SET
# Added "Flashcards Cho Bé" to CATEGORY_SET
# Added "Flashcard Tiếng Anh - Ielts" to CATEGORY_SET
# Added "Flashcard Tiếng Anh - Toefl" to CATEGORY_SET
# Added "Flashcard Tiếng Anh - Toeic" to CATEGORY_SET
# Added "Flashcard Tiếng Anh - Từ Vựng - Chủ Đề" to CATEGORY_SET
# Done
# Done
# Added "Lịch Bloc" to CATEGORY_SET
# Added "Lịch Bàn" to CATEGORY_SET
# Added "Lịch Tờ - Lịch Lò Xo" to CATEGORY_SET
# Added "Sổ Agenda" to CATEGORY_SET
# Done
# Added "Máy Tính Khoa Học" to CATEGORY_SET
# Added "Máy tính bỏ túi" to CATEGORY_SET
# Added "Máy tính để bàn" to CATEGORY_SET
# Added "Phụ Kiện Trang Trí Máy Tính" to CATEGORY_SET
# Done
# Added "Giấy các loại" to CATEGORY_SET
# Added "Hộp và thùng lưu trữ" to CATEGORY_SET
# Added "Các loại giấy khác" to CATEGORY_SET
# Added "Giấy Notes" to CATEGORY_SET
# Added "Giấy bìa - Decal" to CATEGORY_SET
# Added "Giấy in - Fax - Photo" to CATEGORY_SET
# Added "Giấy thủ công" to CATEGORY_SET
# Done
# Done
# Added "Bàn cắt giấy" to CATEGORY_SET
# Added "Máy ép plastic" to CATEGORY_SET
# Added "Máy đóng gáy lò xo" to CATEGORY_SET
# Added "Thiết bị văn phòng khác" to CATEGORY_SET
# Done
# Added "Tập 4 ô ly" to CATEGORY_SET
# Added "Tập 5 ô ly" to CATEGORY_SET
# Added "Tập kẻ ngang" to CATEGORY_SET
# Done
# Added "Bao lì xì" to CATEGORY_SET
# Added "Thể Loại Khác" to CATEGORY_SET
# Added "Đĩa Nhạc" to CATEGORY_SET
# Added "Đĩa Phim" to CATEGORY_SET
# Done
# Done
# Done
# Added "Du lịch - Khách sạn" to CATEGORY_SET
# Added "Dịch vụ khác" to CATEGORY_SET
# Added "Khóa học" to CATEGORY_SET
# Added "Nha khoa - Sức khỏe" to CATEGORY_SET
# Added "Nhà hàng - Ăn uống" to CATEGORY_SET
# Added "Phiếu quà tặng" to CATEGORY_SET
# Added "Spa & Làm đẹp" to CATEGORY_SET
# Added "Sự kiện - Giải trí" to CATEGORY_SET
# Added "Khách sạn - Resort" to CATEGORY_SET
# Added "Sim 3G/4G - Bộ phát Wifi" to CATEGORY_SET
# Added "Tour du lịch" to CATEGORY_SET
# Added "Vé tham quan - du lịch" to CATEGORY_SET
# Added "Khách sạn - Resort miền Bắc" to CATEGORY_SET
# Added "Khách sạn - Resort miền Nam" to CATEGORY_SET
# Added "Khách sạn - Resort miền Trung" to CATEGORY_SET
# Done
# Added "Tour nước ngoài" to CATEGORY_SET
# Added "Tour trong nước" to CATEGORY_SET
# Added "Tour miền Bắc" to CATEGORY_SET
# Added "Tour miền Nam" to CATEGORY_SET
# Added "Tour miền Trung" to CATEGORY_SET
# Done
# Done
# Done
# Added "Khóa học IT và lập trình" to CATEGORY_SET
# Added "Khóa học KYNA" to CATEGORY_SET
# Added "Khóa học Kế toán - Tài chính - Đầu tư" to CATEGORY_SET
# Added "Khóa học kinh doanh - marketing" to CATEGORY_SET
# Added "Khóa học nghệ thuật và chủ đề khác" to CATEGORY_SET
# Added "Khóa học ngoại ngữ" to CATEGORY_SET
# Added "Khóa học nuôi dạy con và kỹ năng cho bé" to CATEGORY_SET
# Added "Khóa học online" to CATEGORY_SET
# Added "Khóa học thiết kế đồ họa và video" to CATEGORY_SET
# Added "Khóa học vi tính văn phòng" to CATEGORY_SET
# Done
# Added "Khám sức khỏe tổng quát" to CATEGORY_SET
# Added "Nha khoa" to CATEGORY_SET
# Done
# Added "Bar - Beer club" to CATEGORY_SET
# Added "Buffet" to CATEGORY_SET
# Added "Cafe - Kem - Bánh" to CATEGORY_SET
# Added "Nhà hàng" to CATEGORY_SET
# Added "Nhà hàng - Quán ăn" to CATEGORY_SET
# Added "Quán ăn" to CATEGORY_SET
# Added "Buffet BBQ" to CATEGORY_SET
# Added "Buffet Chay" to CATEGORY_SET
# Added "Buffet Gọi Món" to CATEGORY_SET
# Added "Buffet Hải Sản" to CATEGORY_SET
# Done
# Done
# Added "Massage Body - Foot" to CATEGORY_SET
# Added "Phòng tập" to CATEGORY_SET
# Added "Phẫu thuật thẩm mỹ" to CATEGORY_SET
# Added "Salon làm đẹp" to CATEGORY_SET
# Added "Spa - Thẩm mỹ viện" to CATEGORY_SET
# Added "GYM" to CATEGORY_SET
# Done
# Done
# Added "Ca nhạc - Phim - Kịch" to CATEGORY_SET
# Added "Studio - Chụp ảnh" to CATEGORY_SET
# Added "Vui chơi - Giải trí" to CATEGORY_SET
# Done
# Done
# Done
